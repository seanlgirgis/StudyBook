# %%
"""
Polar coordinates are an alternative way of representing Cartesian coordinates or Complex Numbers.

A complex number  Capture.PNG

is completely determined by its real part  and imaginary part .
Here,  is the imaginary unit.
A polar coordinate () Capture.PNG

is completely determined by modulus  and phase angle .

If we convert complex number  to its polar coordinate, we find:
: Distance from  to origin, i.e., 
: Counter clockwise angle measured from the positive -axis to the line segment 
that joins  to the origin.

Python's cmath module provides access to the mathematical functions for complex numbers.


This tool returns the phase of complex number  (also known as the argument of ).

>>> phase(complex(-1.0, 0.0))
3.1415926535897931

This tool returns the modulus (absolute value) of complex number .

>>> abs(complex(-1.0, 0.0))
1.0
Task
You are given a complex . Your task is to convert it to polar coordinates.

Input Format

A single line containing the complex number . Note: complex() function can be used in python to convert the input as a complex number.

Constraints

Given number is a valid complex number

Output Format

Output two lines:
The first line should contain the value of .
The second line should contain the value of .

Sample Input

  1+2j
Sample Output

 2.23606797749979 
 1.1071487177940904
Note: The output should be correct up to 3 decimal places.

"""
# Enter your code here. Read input from STDIN. Print output to STDOUT
import cmath

z = complex(input())

print(f"{abs(z):.3f}")
print(f"{cmath.phase(z):.3f}")
# Out:
#  1+2j
# 2.236
# 1.107

# %%
"""
They want you to print a **palindromic number triangle**.

A palindrome means it reads the same forward and backward.

For each row `i`, print:

```text
1 2 3 ... i ... 3 2 1
```

But printed as one number, with no spaces.

For example, when `i = 4`:

```text
1234321
```

## Input needed

One integer:

```text
N
```

`N` is the number of rows.

Constraint:

```text
0 < N < 10
```

So `N` can be from `1` to `9`.

## Output needed

Print `N` rows.

Each row builds up from `1` to the row number, then goes back down to `1`.

## Example 1

Input:

```text
5
```

Output:

```text
1
121
12321
1234321
123454321
```

## Example 2

Input:

```text
3
```

Output:

```text
1
121
12321
```

## Example 3

Input:

```text
7
```

Output:

```text
1
121
12321
1234321
123454321
12345654321
1234567654321
```

## The annoying HackerRank restriction

They say:

```text
No strings
Only one for-loop
Only one print statement
```

So they do **not** want the easy string solution like:

```python
print("12321")
```

They want a math trick.

For row `i`, the value can be created using:

```python
((10 ** i - 1) // 9) ** 2
```

Example:

```text
i = 1 -> 1 ** 2 = 1
i = 2 -> 11 ** 2 = 121
i = 3 -> 111 ** 2 = 12321
i = 4 -> 1111 ** 2 = 1234321
```

So the final HackerRank-style solution is:

```python
for i in range(1, int(input()) + 1):
    print(((10 ** i - 1) // 9) ** 2)
```

"""
for i in range(1, int(input()) + 1):
    print(((10 ** i - 1) // 9) ** 2)
# Out:
#  4
# 1
# 121
# 12321
# 1234321

# %%
"""
They want you to practice Python’s division tools:

```python
//
%
divmod()
```

No full solution yet.

## What the problem wants

You read **two integers**:

```text
a
b
```

Then you print **three lines**:

```text
line 1: integer division result of a // b
line 2: remainder result of a % b
line 3: tuple result of divmod(a, b)
```

## Meaning

For:

```text
177
10
```

You are dividing:

```text
177 by 10
```

Integer division:

```text
177 // 10 = 17
```

Remainder:

```text
177 % 10 = 7
```

Together:

```text
divmod(177, 10) = (17, 7)
```

## Input format

Two separate lines:

```text
a
b
```

Example:

```text
177
10
```

So:

```text
a = 177
b = 10
```

## Output format

Three separate lines:

```text
a // b
a % b
divmod(a, b)
```

## Example 1

Input:

```text
177
10
```

Expected output:

```text
17
7
(17, 7)
```

## Example 2

Input:

```text
20
6
```

Expected output:

```text
3
2
(3, 2)
```

Because:

```text
20 // 6 = 3
20 % 6 = 2
```

## Example 3

Input:

```text
9
3
```

Expected output:

```text
3
0
(3, 0)
```

Because `9` divides evenly by `3`, so the remainder is `0`.
"""
# Enter your code here. Read input from STDIN. Print output to STDOUT
n1 = int(input())
n2 = int(input())
t = divmod(n1,n2)
print(t[0])
print(t[1])
print(t)
# Out:
#  20
#  6
# 3
# 2
# (3, 2)

# %%
"""
They want you to practice Python’s power function:

```python
pow()
```

No full solution yet.

## What the problem wants

You read **three integers**:

```text
a
b
m
```

Then you print **two lines**:

```text
line 1: a raised to the power b
line 2: a raised to the power b, then modulo m
```

In math words:

```text
line 1: a^b
line 2: (a^b) % m
```

Python gives you a shortcut for the second one:

```python
pow(a, b, m)
```

This means:

```text
calculate a^b modulo m
```

## Input format

Three separate lines:

```text
a
b
m
```

Example:

```text
3
4
5
```

So:

```text
a = 3
b = 4
m = 5
```

## Output format

Two separate lines:

```text
a^b
(a^b) % m
```

## Example 1

Input:

```text
3
4
5
```

Expected output:

```text
81
1
```

Because:

```text
3^4 = 81
81 % 5 = 1
```

## Example 2

Input:

```text
2
3
3
```

Expected output:

```text
8
2
```

Because:

```text
2^3 = 8
8 % 3 = 2
```

## Example 3

Input:

```text
10
2
7
```

Expected output:

```text
100
2
```

Because:

```text
10^2 = 100
100 % 7 = 2
```

"""
# Enter your code here. Read input from STDIN. Print output to STDOUT
a = int(input())
b = int(input())
m = int(input())
print(pow(a,b))
print(pow(a,b,m))
# Out:
#  3
#  4
#  5
# 81
# 1

# %%
"""
They want you to practice Python’s ability to handle **very large integers**.

No full solution yet.

## What the problem wants

You read **four integers**:

```text
a
b
c
d
```

Then calculate:

```text
a^b + c^d
```

In Python syntax, power is:

```python
a ** b
```

or:

```python
pow(a, b)
```

So mathematically:

```text
a raised to b
+
c raised to d
```

## Input format

Four separate lines:

```text
a
b
c
d
```

Example:

```text
9
29
7
27
```

So:

```text
a = 9
b = 29
c = 7
d = 27
```

## Output format

One line only:

```text
a^b + c^d
```

## Example 1

Input:

```text
9
29
7
27
```

Expected output:

```text
4710194409608608369201743232
```

Meaning:

```text
9^29 + 7^27
```

## Example 2

Input:

```text
2
3
4
2
```

Expected output:

```text
24
```

Because:

```text
2^3 = 8
4^2 = 16
8 + 16 = 24
```

## Example 3

Input:

```text
10
2
5
3
```

Expected output:

```text
225
```

Because:

```text
10^2 = 100
5^3 = 125
100 + 125 = 225
```

The main idea is simply:

```text
read 4 numbers
calculate first power
calculate second power
add them
print the result
```

"""
a = int(input())
b = int(input())
c = int(input())
d = int(input())
print(pow(a,b) + pow(c,d))

# %%
"""
They want you to print a **number triangle**, but with a restriction:

```text
No strings
Only arithmetic
Only one for-loop
Only one print statement
```

## What the problem wants

You are given one integer:

```text
N
```

You must print `N - 1` lines.

Each line `i` prints the digit `i` repeated `i` times.

So:

```text
i = 1 -> 1
i = 2 -> 22
i = 3 -> 333
i = 4 -> 4444
```

## Input needed

One integer:

```text
N
```

Example:

```text
5
```

## Output needed

Print rows from `1` to `N - 1`.

For input:

```text
5
```

Output:

```text
1
22
333
4444
```

Notice it stops at `4`, because the height is:

```text
N - 1
```

## Example 1

Input:

```text
3
```

Expected output:

```text
1
22
```

## Example 2

Input:

```text
6
```

Expected output:

```text
1
22
333
4444
55555
```

## Important restriction

They do **not** want this kind of solution:

```python
print(str(i) * i)
```

Because that uses strings.

They want a math trick that creates:

```text
1
22
333
4444
```

using arithmetic only.

Hint without giving the full answer:

```text
1      = 1 * 1
22     = 2 * 11
333    = 3 * 111
4444   = 4 * 1111
```

So the key is finding a numeric way to create:

```text
1
11
111
1111
```

for each row.

"""
for i in range(1,int(input())): #More than 2 lines will result in 0 score. Do not leave a blank line also
    print (i * (10**i -1)//9 )
# Out:
#  5
# 1
# 22
# 333
# 4444
