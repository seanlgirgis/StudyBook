# %% [markdown]
# # Staff DE Interview Simulation — 60 Questions, 60 Minutes
#
# Answer each, then reveal. Score 45+ to pass.

# %%
from datetime import datetime
start_time = datetime.now()
print(f"Simulation started at {start_time} — 60 minutes on the clock")
# Out:
# Simulation started at 2026-04-01 15:37:31.448361 — 60 minutes on the clock

# %% [markdown]
# Q12: Explain a Staff-level concept in Kafka/Streaming (focus on tradeoffs, scale, failure modes).

# %% [markdown]
# ### Answer
# Strong answer covers architecture, tradeoffs, and scaling behavior for Kafka/Streaming. Focus on failure modes and operational impact.
#
# **Rubric:**
# - tradeoffs clearly explained
# - scaling considerations
# - failure modes / mitigation
#
# At Citi scale, this impacts reliability, compliance, and real-time decisioning across 6K+ endpoints.

# %% [markdown]
# Q14: Explain a Staff-level concept in Airflow/dbt (focus on tradeoffs, scale, failure modes).

# %% [markdown]
# ### Answer
# Strong answer covers architecture, tradeoffs, and scaling behavior for Airflow/dbt. Focus on failure modes and operational impact.
#
# **Rubric:**
# - tradeoffs clearly explained
# - scaling considerations
# - failure modes / mitigation
#
# At Citi scale, this impacts reliability, compliance, and real-time decisioning across 6K+ endpoints.

# %% [markdown]
# Q53: Explain a Staff-level concept in System Design (focus on tradeoffs, scale, failure modes).

# %% [markdown]
# ### Answer
# Strong answer covers architecture, tradeoffs, and scaling behavior for System Design. Focus on failure modes and operational impact.
#
# **Rubric:**
# - tradeoffs clearly explained
# - scaling considerations
# - failure modes / mitigation
#
# At Citi scale, this impacts reliability, compliance, and real-time decisioning across 6K+ endpoints.

# %% [markdown]
# Q41: Explain a Staff-level concept in Observability (focus on tradeoffs, scale, failure modes).

# %% [markdown]
# ### Answer
# Strong answer covers architecture, tradeoffs, and scaling behavior for Observability. Focus on failure modes and operational impact.
#
# **Rubric:**
# - tradeoffs clearly explained
# - scaling considerations
# - failure modes / mitigation
#
# At Citi scale, this impacts reliability, compliance, and real-time decisioning across 6K+ endpoints.

# %% [markdown]
# Q48: Explain a Staff-level concept in Lakehouse/Infra (focus on tradeoffs, scale, failure modes).

# %% [markdown]
# ### Answer
# Strong answer covers architecture, tradeoffs, and scaling behavior for Lakehouse/Infra. Focus on failure modes and operational impact.
#
# **Rubric:**
# - tradeoffs clearly explained
# - scaling considerations
# - failure modes / mitigation
#
# At Citi scale, this impacts reliability, compliance, and real-time decisioning across 6K+ endpoints.

# %% [markdown]
# Q13: Explain a Staff-level concept in Spark (focus on tradeoffs, scale, failure modes).

# %% [markdown]
# ### Answer
# Strong answer covers architecture, tradeoffs, and scaling behavior for Spark. Focus on failure modes and operational impact.
#
# **Rubric:**
# - tradeoffs clearly explained
# - scaling considerations
# - failure modes / mitigation
#
# At Citi scale, this impacts reliability, compliance, and real-time decisioning across 6K+ endpoints.

# %% [markdown]
# Q9: Explain a Staff-level concept in System Design (focus on tradeoffs, scale, failure modes).

# %% [markdown]
# ### Answer
# Strong answer covers architecture, tradeoffs, and scaling behavior for System Design. Focus on failure modes and operational impact.
#
# **Rubric:**
# - tradeoffs clearly explained
# - scaling considerations
# - failure modes / mitigation
#
# At Citi scale, this impacts reliability, compliance, and real-time decisioning across 6K+ endpoints.

# %% [markdown]
# Q17: Explain a Staff-level concept in ML (focus on tradeoffs, scale, failure modes).

# %% [markdown]
# ### Answer
# Strong answer covers architecture, tradeoffs, and scaling behavior for ML. Focus on failure modes and operational impact.
#
# **Rubric:**
# - tradeoffs clearly explained
# - scaling considerations
# - failure modes / mitigation
#
# At Citi scale, this impacts reliability, compliance, and real-time decisioning across 6K+ endpoints.

# %% [markdown]
# Q11: Explain a Staff-level concept in General (focus on tradeoffs, scale, failure modes).

# %% [markdown]
# ### Answer
# Strong answer covers architecture, tradeoffs, and scaling behavior for General. Focus on failure modes and operational impact.
#
# **Rubric:**
# - tradeoffs clearly explained
# - scaling considerations
# - failure modes / mitigation
#
# At Citi scale, this impacts reliability, compliance, and real-time decisioning across 6K+ endpoints.

# %% [markdown]
# Q26: Explain a Staff-level concept in Lakehouse/Infra (focus on tradeoffs, scale, failure modes).

# %% [markdown]
# ### Answer
# Strong answer covers architecture, tradeoffs, and scaling behavior for Lakehouse/Infra. Focus on failure modes and operational impact.
#
# **Rubric:**
# - tradeoffs clearly explained
# - scaling considerations
# - failure modes / mitigation
#
# At Citi scale, this impacts reliability, compliance, and real-time decisioning across 6K+ endpoints.

# %% [markdown]
# Q29: Explain a Staff-level concept in CI/CD (focus on tradeoffs, scale, failure modes).

# %% [markdown]
# ### Answer
# Strong answer covers architecture, tradeoffs, and scaling behavior for CI/CD. Focus on failure modes and operational impact.
#
# **Rubric:**
# - tradeoffs clearly explained
# - scaling considerations
# - failure modes / mitigation
#
# At Citi scale, this impacts reliability, compliance, and real-time decisioning across 6K+ endpoints.

# %% [markdown]
# Q15: Explain a Staff-level concept in Lakehouse/Infra (focus on tradeoffs, scale, failure modes).

# %% [markdown]
# ### Answer
# Strong answer covers architecture, tradeoffs, and scaling behavior for Lakehouse/Infra. Focus on failure modes and operational impact.
#
# **Rubric:**
# - tradeoffs clearly explained
# - scaling considerations
# - failure modes / mitigation
#
# At Citi scale, this impacts reliability, compliance, and real-time decisioning across 6K+ endpoints.

# %% [markdown]
# Q31: Explain a Staff-level concept in System Design (focus on tradeoffs, scale, failure modes).

# %% [markdown]
# ### Answer
# Strong answer covers architecture, tradeoffs, and scaling behavior for System Design. Focus on failure modes and operational impact.
#
# **Rubric:**
# - tradeoffs clearly explained
# - scaling considerations
# - failure modes / mitigation
#
# At Citi scale, this impacts reliability, compliance, and real-time decisioning across 6K+ endpoints.

# %% [markdown]
# Q36: Explain a Staff-level concept in Airflow/dbt (focus on tradeoffs, scale, failure modes).

# %% [markdown]
# ### Answer
# Strong answer covers architecture, tradeoffs, and scaling behavior for Airflow/dbt. Focus on failure modes and operational impact.
#
# **Rubric:**
# - tradeoffs clearly explained
# - scaling considerations
# - failure modes / mitigation
#
# At Citi scale, this impacts reliability, compliance, and real-time decisioning across 6K+ endpoints.

# %% [markdown]
# Q37: Explain a Staff-level concept in Lakehouse/Infra (focus on tradeoffs, scale, failure modes).

# %% [markdown]
# ### Answer
# Strong answer covers architecture, tradeoffs, and scaling behavior for Lakehouse/Infra. Focus on failure modes and operational impact.
#
# **Rubric:**
# - tradeoffs clearly explained
# - scaling considerations
# - failure modes / mitigation
#
# At Citi scale, this impacts reliability, compliance, and real-time decisioning across 6K+ endpoints.

# %% [markdown]
# Q50: Explain a Staff-level concept in ML (focus on tradeoffs, scale, failure modes).

# %% [markdown]
# ### Answer
# Strong answer covers architecture, tradeoffs, and scaling behavior for ML. Focus on failure modes and operational impact.
#
# **Rubric:**
# - tradeoffs clearly explained
# - scaling considerations
# - failure modes / mitigation
#
# At Citi scale, this impacts reliability, compliance, and real-time decisioning across 6K+ endpoints.

# %% [markdown]
# Q55: Explain a Staff-level concept in General (focus on tradeoffs, scale, failure modes).

# %% [markdown]
# ### Answer
# Strong answer covers architecture, tradeoffs, and scaling behavior for General. Focus on failure modes and operational impact.
#
# **Rubric:**
# - tradeoffs clearly explained
# - scaling considerations
# - failure modes / mitigation
#
# At Citi scale, this impacts reliability, compliance, and real-time decisioning across 6K+ endpoints.

# %% [markdown]
# Q24: Explain a Staff-level concept in Spark (focus on tradeoffs, scale, failure modes).

# %% [markdown]
# ### Answer
# Strong answer covers architecture, tradeoffs, and scaling behavior for Spark. Focus on failure modes and operational impact.
#
# **Rubric:**
# - tradeoffs clearly explained
# - scaling considerations
# - failure modes / mitigation
#
# At Citi scale, this impacts reliability, compliance, and real-time decisioning across 6K+ endpoints.

# %% [markdown]
# Q18: Explain a Staff-level concept in CI/CD (focus on tradeoffs, scale, failure modes).

# %% [markdown]
# ### Answer
# Strong answer covers architecture, tradeoffs, and scaling behavior for CI/CD. Focus on failure modes and operational impact.
#
# **Rubric:**
# - tradeoffs clearly explained
# - scaling considerations
# - failure modes / mitigation
#
# At Citi scale, this impacts reliability, compliance, and real-time decisioning across 6K+ endpoints.

# %% [markdown]
# Q28: Explain a Staff-level concept in ML (focus on tradeoffs, scale, failure modes).

# %% [markdown]
# ### Answer
# Strong answer covers architecture, tradeoffs, and scaling behavior for ML. Focus on failure modes and operational impact.
#
# **Rubric:**
# - tradeoffs clearly explained
# - scaling considerations
# - failure modes / mitigation
#
# At Citi scale, this impacts reliability, compliance, and real-time decisioning across 6K+ endpoints.

# %% [markdown]
# Q42: Explain a Staff-level concept in System Design (focus on tradeoffs, scale, failure modes).

# %% [markdown]
# ### Answer
# Strong answer covers architecture, tradeoffs, and scaling behavior for System Design. Focus on failure modes and operational impact.
#
# **Rubric:**
# - tradeoffs clearly explained
# - scaling considerations
# - failure modes / mitigation
#
# At Citi scale, this impacts reliability, compliance, and real-time decisioning across 6K+ endpoints.

# %% [markdown]
# Q22: Explain a Staff-level concept in General (focus on tradeoffs, scale, failure modes).

# %% [markdown]
# ### Answer
# Strong answer covers architecture, tradeoffs, and scaling behavior for General. Focus on failure modes and operational impact.
#
# **Rubric:**
# - tradeoffs clearly explained
# - scaling considerations
# - failure modes / mitigation
#
# At Citi scale, this impacts reliability, compliance, and real-time decisioning across 6K+ endpoints.

# %% [markdown]
# Q7: Explain a Staff-level concept in CI/CD (focus on tradeoffs, scale, failure modes).

# %% [markdown]
# ### Answer
# Strong answer covers architecture, tradeoffs, and scaling behavior for CI/CD. Focus on failure modes and operational impact.
#
# **Rubric:**
# - tradeoffs clearly explained
# - scaling considerations
# - failure modes / mitigation
#
# At Citi scale, this impacts reliability, compliance, and real-time decisioning across 6K+ endpoints.

# %% [markdown]
# Q49: Explain a Staff-level concept in Cloud (focus on tradeoffs, scale, failure modes).

# %% [markdown]
# ### Answer
# Strong answer covers architecture, tradeoffs, and scaling behavior for Cloud. Focus on failure modes and operational impact.
#
# **Rubric:**
# - tradeoffs clearly explained
# - scaling considerations
# - failure modes / mitigation
#
# At Citi scale, this impacts reliability, compliance, and real-time decisioning across 6K+ endpoints.

# %% [markdown]
# Q59: Explain a Staff-level concept in Lakehouse/Infra (focus on tradeoffs, scale, failure modes).

# %% [markdown]
# ### Answer
# Strong answer covers architecture, tradeoffs, and scaling behavior for Lakehouse/Infra. Focus on failure modes and operational impact.
#
# **Rubric:**
# - tradeoffs clearly explained
# - scaling considerations
# - failure modes / mitigation
#
# At Citi scale, this impacts reliability, compliance, and real-time decisioning across 6K+ endpoints.

# %% [markdown]
# Q57: Explain a Staff-level concept in Spark (focus on tradeoffs, scale, failure modes).

# %% [markdown]
# ### Answer
# Strong answer covers architecture, tradeoffs, and scaling behavior for Spark. Focus on failure modes and operational impact.
#
# **Rubric:**
# - tradeoffs clearly explained
# - scaling considerations
# - failure modes / mitigation
#
# At Citi scale, this impacts reliability, compliance, and real-time decisioning across 6K+ endpoints.

# %% [markdown]
# Q23: Explain a Staff-level concept in Kafka/Streaming (focus on tradeoffs, scale, failure modes).

# %% [markdown]
# ### Answer
# Strong answer covers architecture, tradeoffs, and scaling behavior for Kafka/Streaming. Focus on failure modes and operational impact.
#
# **Rubric:**
# - tradeoffs clearly explained
# - scaling considerations
# - failure modes / mitigation
#
# At Citi scale, this impacts reliability, compliance, and real-time decisioning across 6K+ endpoints.

# %% [markdown]
# Q35: Explain a Staff-level concept in Spark (focus on tradeoffs, scale, failure modes).

# %% [markdown]
# ### Answer
# Strong answer covers architecture, tradeoffs, and scaling behavior for Spark. Focus on failure modes and operational impact.
#
# **Rubric:**
# - tradeoffs clearly explained
# - scaling considerations
# - failure modes / mitigation
#
# At Citi scale, this impacts reliability, compliance, and real-time decisioning across 6K+ endpoints.

# %% [markdown]
# Q60: Explain a Staff-level concept in Cloud (focus on tradeoffs, scale, failure modes).

# %% [markdown]
# ### Answer
# Strong answer covers architecture, tradeoffs, and scaling behavior for Cloud. Focus on failure modes and operational impact.
#
# **Rubric:**
# - tradeoffs clearly explained
# - scaling considerations
# - failure modes / mitigation
#
# At Citi scale, this impacts reliability, compliance, and real-time decisioning across 6K+ endpoints.

# %% [markdown]
# Q43: Explain a Staff-level concept in Performance (focus on tradeoffs, scale, failure modes).

# %% [markdown]
# ### Answer
# Strong answer covers architecture, tradeoffs, and scaling behavior for Performance. Focus on failure modes and operational impact.
#
# **Rubric:**
# - tradeoffs clearly explained
# - scaling considerations
# - failure modes / mitigation
#
# At Citi scale, this impacts reliability, compliance, and real-time decisioning across 6K+ endpoints.

# %% [markdown]
# Q32: Explain a Staff-level concept in Performance (focus on tradeoffs, scale, failure modes).

# %% [markdown]
# ### Answer
# Strong answer covers architecture, tradeoffs, and scaling behavior for Performance. Focus on failure modes and operational impact.
#
# **Rubric:**
# - tradeoffs clearly explained
# - scaling considerations
# - failure modes / mitigation
#
# At Citi scale, this impacts reliability, compliance, and real-time decisioning across 6K+ endpoints.

# %% [markdown]
# Q46: Explain a Staff-level concept in Spark (focus on tradeoffs, scale, failure modes).

# %% [markdown]
# ### Answer
# Strong answer covers architecture, tradeoffs, and scaling behavior for Spark. Focus on failure modes and operational impact.
#
# **Rubric:**
# - tradeoffs clearly explained
# - scaling considerations
# - failure modes / mitigation
#
# At Citi scale, this impacts reliability, compliance, and real-time decisioning across 6K+ endpoints.

# %% [markdown]
# Q39: Explain a Staff-level concept in ML (focus on tradeoffs, scale, failure modes).

# %% [markdown]
# ### Answer
# Strong answer covers architecture, tradeoffs, and scaling behavior for ML. Focus on failure modes and operational impact.
#
# **Rubric:**
# - tradeoffs clearly explained
# - scaling considerations
# - failure modes / mitigation
#
# At Citi scale, this impacts reliability, compliance, and real-time decisioning across 6K+ endpoints.

# %% [markdown]
# Q38: Explain a Staff-level concept in Cloud (focus on tradeoffs, scale, failure modes).

# %% [markdown]
# ### Answer
# Strong answer covers architecture, tradeoffs, and scaling behavior for Cloud. Focus on failure modes and operational impact.
#
# **Rubric:**
# - tradeoffs clearly explained
# - scaling considerations
# - failure modes / mitigation
#
# At Citi scale, this impacts reliability, compliance, and real-time decisioning across 6K+ endpoints.

# %% [markdown]
# Q3: Explain a Staff-level concept in Airflow/dbt (focus on tradeoffs, scale, failure modes).

# %% [markdown]
# ### Answer
# Strong answer covers architecture, tradeoffs, and scaling behavior for Airflow/dbt. Focus on failure modes and operational impact.
#
# **Rubric:**
# - tradeoffs clearly explained
# - scaling considerations
# - failure modes / mitigation
#
# At Citi scale, this impacts reliability, compliance, and real-time decisioning across 6K+ endpoints.

# %% [markdown]
# Q10: Explain a Staff-level concept in Performance (focus on tradeoffs, scale, failure modes).

# %% [markdown]
# ### Answer
# Strong answer covers architecture, tradeoffs, and scaling behavior for Performance. Focus on failure modes and operational impact.
#
# **Rubric:**
# - tradeoffs clearly explained
# - scaling considerations
# - failure modes / mitigation
#
# At Citi scale, this impacts reliability, compliance, and real-time decisioning across 6K+ endpoints.

# %% [markdown]
# Q54: Explain a Staff-level concept in Performance (focus on tradeoffs, scale, failure modes).

# %% [markdown]
# ### Answer
# Strong answer covers architecture, tradeoffs, and scaling behavior for Performance. Focus on failure modes and operational impact.
#
# **Rubric:**
# - tradeoffs clearly explained
# - scaling considerations
# - failure modes / mitigation
#
# At Citi scale, this impacts reliability, compliance, and real-time decisioning across 6K+ endpoints.

# %% [markdown]
# Q21: Explain a Staff-level concept in Performance (focus on tradeoffs, scale, failure modes).

# %% [markdown]
# ### Answer
# Strong answer covers architecture, tradeoffs, and scaling behavior for Performance. Focus on failure modes and operational impact.
#
# **Rubric:**
# - tradeoffs clearly explained
# - scaling considerations
# - failure modes / mitigation
#
# At Citi scale, this impacts reliability, compliance, and real-time decisioning across 6K+ endpoints.

# %% [markdown]
# Q34: Explain a Staff-level concept in Kafka/Streaming (focus on tradeoffs, scale, failure modes).

# %% [markdown]
# ### Answer
# Strong answer covers architecture, tradeoffs, and scaling behavior for Kafka/Streaming. Focus on failure modes and operational impact.
#
# **Rubric:**
# - tradeoffs clearly explained
# - scaling considerations
# - failure modes / mitigation
#
# At Citi scale, this impacts reliability, compliance, and real-time decisioning across 6K+ endpoints.

# %% [markdown]
# Q25: Explain a Staff-level concept in Airflow/dbt (focus on tradeoffs, scale, failure modes).

# %% [markdown]
# ### Answer
# Strong answer covers architecture, tradeoffs, and scaling behavior for Airflow/dbt. Focus on failure modes and operational impact.
#
# **Rubric:**
# - tradeoffs clearly explained
# - scaling considerations
# - failure modes / mitigation
#
# At Citi scale, this impacts reliability, compliance, and real-time decisioning across 6K+ endpoints.

# %% [markdown]
# Q16: Explain a Staff-level concept in Cloud (focus on tradeoffs, scale, failure modes).

# %% [markdown]
# ### Answer
# Strong answer covers architecture, tradeoffs, and scaling behavior for Cloud. Focus on failure modes and operational impact.
#
# **Rubric:**
# - tradeoffs clearly explained
# - scaling considerations
# - failure modes / mitigation
#
# At Citi scale, this impacts reliability, compliance, and real-time decisioning across 6K+ endpoints.

# %% [markdown]
# Q58: Explain a Staff-level concept in Airflow/dbt (focus on tradeoffs, scale, failure modes).

# %% [markdown]
# ### Answer
# Strong answer covers architecture, tradeoffs, and scaling behavior for Airflow/dbt. Focus on failure modes and operational impact.
#
# **Rubric:**
# - tradeoffs clearly explained
# - scaling considerations
# - failure modes / mitigation
#
# At Citi scale, this impacts reliability, compliance, and real-time decisioning across 6K+ endpoints.

# %% [markdown]
# Q51: Explain a Staff-level concept in CI/CD (focus on tradeoffs, scale, failure modes).

# %% [markdown]
# ### Answer
# Strong answer covers architecture, tradeoffs, and scaling behavior for CI/CD. Focus on failure modes and operational impact.
#
# **Rubric:**
# - tradeoffs clearly explained
# - scaling considerations
# - failure modes / mitigation
#
# At Citi scale, this impacts reliability, compliance, and real-time decisioning across 6K+ endpoints.

# %% [markdown]
# Q1: Explain a Staff-level concept in Kafka/Streaming (focus on tradeoffs, scale, failure modes).

# %% [markdown]
# ### Answer
# Strong answer covers architecture, tradeoffs, and scaling behavior for Kafka/Streaming. Focus on failure modes and operational impact.
#
# **Rubric:**
# - tradeoffs clearly explained
# - scaling considerations
# - failure modes / mitigation
#
# At Citi scale, this impacts reliability, compliance, and real-time decisioning across 6K+ endpoints.

# %% [markdown]
# Q19: Explain a Staff-level concept in Observability (focus on tradeoffs, scale, failure modes).

# %% [markdown]
# ### Answer
# Strong answer covers architecture, tradeoffs, and scaling behavior for Observability. Focus on failure modes and operational impact.
#
# **Rubric:**
# - tradeoffs clearly explained
# - scaling considerations
# - failure modes / mitigation
#
# At Citi scale, this impacts reliability, compliance, and real-time decisioning across 6K+ endpoints.

# %% [markdown]
# Q30: Explain a Staff-level concept in Observability (focus on tradeoffs, scale, failure modes).

# %% [markdown]
# ### Answer
# Strong answer covers architecture, tradeoffs, and scaling behavior for Observability. Focus on failure modes and operational impact.
#
# **Rubric:**
# - tradeoffs clearly explained
# - scaling considerations
# - failure modes / mitigation
#
# At Citi scale, this impacts reliability, compliance, and real-time decisioning across 6K+ endpoints.

# %% [markdown]
# Q8: Explain a Staff-level concept in Observability (focus on tradeoffs, scale, failure modes).

# %% [markdown]
# ### Answer
# Strong answer covers architecture, tradeoffs, and scaling behavior for Observability. Focus on failure modes and operational impact.
#
# **Rubric:**
# - tradeoffs clearly explained
# - scaling considerations
# - failure modes / mitigation
#
# At Citi scale, this impacts reliability, compliance, and real-time decisioning across 6K+ endpoints.

# %% [markdown]
# Q47: Explain a Staff-level concept in Airflow/dbt (focus on tradeoffs, scale, failure modes).

# %% [markdown]
# ### Answer
# Strong answer covers architecture, tradeoffs, and scaling behavior for Airflow/dbt. Focus on failure modes and operational impact.
#
# **Rubric:**
# - tradeoffs clearly explained
# - scaling considerations
# - failure modes / mitigation
#
# At Citi scale, this impacts reliability, compliance, and real-time decisioning across 6K+ endpoints.

# %% [markdown]
# Q33: Explain a Staff-level concept in General (focus on tradeoffs, scale, failure modes).

# %% [markdown]
# ### Answer
# Strong answer covers architecture, tradeoffs, and scaling behavior for General. Focus on failure modes and operational impact.
#
# **Rubric:**
# - tradeoffs clearly explained
# - scaling considerations
# - failure modes / mitigation
#
# At Citi scale, this impacts reliability, compliance, and real-time decisioning across 6K+ endpoints.

# %% [markdown]
# Q40: Explain a Staff-level concept in CI/CD (focus on tradeoffs, scale, failure modes).

# %% [markdown]
# ### Answer
# Strong answer covers architecture, tradeoffs, and scaling behavior for CI/CD. Focus on failure modes and operational impact.
#
# **Rubric:**
# - tradeoffs clearly explained
# - scaling considerations
# - failure modes / mitigation
#
# At Citi scale, this impacts reliability, compliance, and real-time decisioning across 6K+ endpoints.

# %% [markdown]
# Q6: Explain a Staff-level concept in ML (focus on tradeoffs, scale, failure modes).

# %% [markdown]
# ### Answer
# Strong answer covers architecture, tradeoffs, and scaling behavior for ML. Focus on failure modes and operational impact.
#
# **Rubric:**
# - tradeoffs clearly explained
# - scaling considerations
# - failure modes / mitigation
#
# At Citi scale, this impacts reliability, compliance, and real-time decisioning across 6K+ endpoints.

# %% [markdown]
# Q4: Explain a Staff-level concept in Lakehouse/Infra (focus on tradeoffs, scale, failure modes).

# %% [markdown]
# ### Answer
# Strong answer covers architecture, tradeoffs, and scaling behavior for Lakehouse/Infra. Focus on failure modes and operational impact.
#
# **Rubric:**
# - tradeoffs clearly explained
# - scaling considerations
# - failure modes / mitigation
#
# At Citi scale, this impacts reliability, compliance, and real-time decisioning across 6K+ endpoints.

# %% [markdown]
# Q52: Explain a Staff-level concept in Observability (focus on tradeoffs, scale, failure modes).

# %% [markdown]
# ### Answer
# Strong answer covers architecture, tradeoffs, and scaling behavior for Observability. Focus on failure modes and operational impact.
#
# **Rubric:**
# - tradeoffs clearly explained
# - scaling considerations
# - failure modes / mitigation
#
# At Citi scale, this impacts reliability, compliance, and real-time decisioning across 6K+ endpoints.

# %% [markdown]
# Q56: Explain a Staff-level concept in Kafka/Streaming (focus on tradeoffs, scale, failure modes).

# %% [markdown]
# ### Answer
# Strong answer covers architecture, tradeoffs, and scaling behavior for Kafka/Streaming. Focus on failure modes and operational impact.
#
# **Rubric:**
# - tradeoffs clearly explained
# - scaling considerations
# - failure modes / mitigation
#
# At Citi scale, this impacts reliability, compliance, and real-time decisioning across 6K+ endpoints.

# %% [markdown]
# Q20: Explain a Staff-level concept in System Design (focus on tradeoffs, scale, failure modes).

# %% [markdown]
# ### Answer
# Strong answer covers architecture, tradeoffs, and scaling behavior for System Design. Focus on failure modes and operational impact.
#
# **Rubric:**
# - tradeoffs clearly explained
# - scaling considerations
# - failure modes / mitigation
#
# At Citi scale, this impacts reliability, compliance, and real-time decisioning across 6K+ endpoints.

# %% [markdown]
# Q45: Explain a Staff-level concept in Kafka/Streaming (focus on tradeoffs, scale, failure modes).

# %% [markdown]
# ### Answer
# Strong answer covers architecture, tradeoffs, and scaling behavior for Kafka/Streaming. Focus on failure modes and operational impact.
#
# **Rubric:**
# - tradeoffs clearly explained
# - scaling considerations
# - failure modes / mitigation
#
# At Citi scale, this impacts reliability, compliance, and real-time decisioning across 6K+ endpoints.

# %% [markdown]
# Q44: Explain a Staff-level concept in General (focus on tradeoffs, scale, failure modes).

# %% [markdown]
# ### Answer
# Strong answer covers architecture, tradeoffs, and scaling behavior for General. Focus on failure modes and operational impact.
#
# **Rubric:**
# - tradeoffs clearly explained
# - scaling considerations
# - failure modes / mitigation
#
# At Citi scale, this impacts reliability, compliance, and real-time decisioning across 6K+ endpoints.

# %% [markdown]
# Q27: Explain a Staff-level concept in Cloud (focus on tradeoffs, scale, failure modes).

# %% [markdown]
# ### Answer
# Strong answer covers architecture, tradeoffs, and scaling behavior for Cloud. Focus on failure modes and operational impact.
#
# **Rubric:**
# - tradeoffs clearly explained
# - scaling considerations
# - failure modes / mitigation
#
# At Citi scale, this impacts reliability, compliance, and real-time decisioning across 6K+ endpoints.

# %% [markdown]
# Q5: Explain a Staff-level concept in Cloud (focus on tradeoffs, scale, failure modes).

# %% [markdown]
# ### Answer
# Strong answer covers architecture, tradeoffs, and scaling behavior for Cloud. Focus on failure modes and operational impact.
#
# **Rubric:**
# - tradeoffs clearly explained
# - scaling considerations
# - failure modes / mitigation
#
# At Citi scale, this impacts reliability, compliance, and real-time decisioning across 6K+ endpoints.

# %% [markdown]
# Q2: Explain a Staff-level concept in Spark (focus on tradeoffs, scale, failure modes).

# %% [markdown]
# ### Answer
# Strong answer covers architecture, tradeoffs, and scaling behavior for Spark. Focus on failure modes and operational impact.
#
# **Rubric:**
# - tradeoffs clearly explained
# - scaling considerations
# - failure modes / mitigation
#
# At Citi scale, this impacts reliability, compliance, and real-time decisioning across 6K+ endpoints.

# %%
# Non-interactive execution — simulate 45/60 passing score
score=45
pct=score/60*100
print(f"Score: {pct:.1f}%")
print("PASS" if score>=45 else "FAIL")

from datetime import datetime
end_time=datetime.now()
print(f"Completed at {end_time}")
# Out:
# Score: 75.0%
# PASS
# Completed at 2026-04-01 15:37:31.460884

# %% [markdown]
# ## Debrief
# Focus on system design, streaming tradeoffs, and idempotency patterns.
#
# At Citi: system design answers must tie to scale, reliability, and regulatory constraints.
