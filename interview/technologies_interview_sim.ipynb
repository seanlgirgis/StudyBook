# %% [markdown]
# # Staff DE Interview Simulation — 60 Questions, 60 Minutes

# %%
from datetime import datetime
start_time = datetime.now()
print(f"Simulation started at {start_time} — 60 minutes on the clock")
# Out:
# Simulation started at 2026-04-01 15:37:31.448361 — 60 minutes on the clock

# %% [markdown]
# ### Question 1
# Explain a Staff-level concept for data engineering category 2.

# %% [markdown]
# ### Answer
# Key explanation for question 1. Include architecture reasoning and tradeoffs. At Citi scale, this matters due to regulatory + volume constraints.
#
# **Rubric:**
# - key concept
# - tradeoff
# - scaling implication

# %% [markdown]
# ### Question 2
# Explain a Staff-level concept for data engineering category 3.

# %% [markdown]
# ### Answer
# Key explanation for question 2. Include architecture reasoning and tradeoffs. At Citi scale, this matters due to regulatory + volume constraints.
#
# **Rubric:**
# - key concept
# - tradeoff
# - scaling implication

# %% [markdown]
# ### Question 3
# Explain a Staff-level concept for data engineering category 4.

# %% [markdown]
# ### Answer
# Key explanation for question 3. Include architecture reasoning and tradeoffs. At Citi scale, this matters due to regulatory + volume constraints.
#
# **Rubric:**
# - key concept
# - tradeoff
# - scaling implication

# %% [markdown]
# ### Question 4
# Explain a Staff-level concept for data engineering category 5.

# %% [markdown]
# ### Answer
# Key explanation for question 4. Include architecture reasoning and tradeoffs. At Citi scale, this matters due to regulatory + volume constraints.
#
# **Rubric:**
# - key concept
# - tradeoff
# - scaling implication

# %% [markdown]
# ### Question 5
# Explain a Staff-level concept for data engineering category 6.

# %% [markdown]
# ### Answer
# Key explanation for question 5. Include architecture reasoning and tradeoffs. At Citi scale, this matters due to regulatory + volume constraints.
#
# **Rubric:**
# - key concept
# - tradeoff
# - scaling implication

# %% [markdown]
# ### Question 6
# Explain a Staff-level concept for data engineering category 7.

# %% [markdown]
# ### Answer
# Key explanation for question 6. Include architecture reasoning and tradeoffs. At Citi scale, this matters due to regulatory + volume constraints.
#
# **Rubric:**
# - key concept
# - tradeoff
# - scaling implication

# %% [markdown]
# ### Question 7
# Explain a Staff-level concept for data engineering category 8.

# %% [markdown]
# ### Answer
# Key explanation for question 7. Include architecture reasoning and tradeoffs. At Citi scale, this matters due to regulatory + volume constraints.
#
# **Rubric:**
# - key concept
# - tradeoff
# - scaling implication

# %% [markdown]
# ### Question 8
# Explain a Staff-level concept for data engineering category 9.

# %% [markdown]
# ### Answer
# Key explanation for question 8. Include architecture reasoning and tradeoffs. At Citi scale, this matters due to regulatory + volume constraints.
#
# **Rubric:**
# - key concept
# - tradeoff
# - scaling implication

# %% [markdown]
# ### Question 9
# Explain a Staff-level concept for data engineering category 10.

# %% [markdown]
# ### Answer
# Key explanation for question 9. Include architecture reasoning and tradeoffs. At Citi scale, this matters due to regulatory + volume constraints.
#
# **Rubric:**
# - key concept
# - tradeoff
# - scaling implication

# %% [markdown]
# ### Question 10
# Explain a Staff-level concept for data engineering category 11.

# %% [markdown]
# ### Answer
# Key explanation for question 10. Include architecture reasoning and tradeoffs. At Citi scale, this matters due to regulatory + volume constraints.
#
# **Rubric:**
# - key concept
# - tradeoff
# - scaling implication

# %% [markdown]
# ### Question 11
# Explain a Staff-level concept for data engineering category 1.

# %% [markdown]
# ### Answer
# Key explanation for question 11. Include architecture reasoning and tradeoffs. At Citi scale, this matters due to regulatory + volume constraints.
#
# **Rubric:**
# - key concept
# - tradeoff
# - scaling implication

# %% [markdown]
# ### Question 12
# Explain a Staff-level concept for data engineering category 2.

# %% [markdown]
# ### Answer
# Key explanation for question 12. Include architecture reasoning and tradeoffs. At Citi scale, this matters due to regulatory + volume constraints.
#
# **Rubric:**
# - key concept
# - tradeoff
# - scaling implication

# %% [markdown]
# ### Question 13
# Explain a Staff-level concept for data engineering category 3.

# %% [markdown]
# ### Answer
# Key explanation for question 13. Include architecture reasoning and tradeoffs. At Citi scale, this matters due to regulatory + volume constraints.
#
# **Rubric:**
# - key concept
# - tradeoff
# - scaling implication

# %% [markdown]
# ### Question 14
# Explain a Staff-level concept for data engineering category 4.

# %% [markdown]
# ### Answer
# Key explanation for question 14. Include architecture reasoning and tradeoffs. At Citi scale, this matters due to regulatory + volume constraints.
#
# **Rubric:**
# - key concept
# - tradeoff
# - scaling implication

# %% [markdown]
# ### Question 15
# Explain a Staff-level concept for data engineering category 5.

# %% [markdown]
# ### Answer
# Key explanation for question 15. Include architecture reasoning and tradeoffs. At Citi scale, this matters due to regulatory + volume constraints.
#
# **Rubric:**
# - key concept
# - tradeoff
# - scaling implication

# %% [markdown]
# ### Question 16
# Explain a Staff-level concept for data engineering category 6.

# %% [markdown]
# ### Answer
# Key explanation for question 16. Include architecture reasoning and tradeoffs. At Citi scale, this matters due to regulatory + volume constraints.
#
# **Rubric:**
# - key concept
# - tradeoff
# - scaling implication

# %% [markdown]
# ### Question 17
# Explain a Staff-level concept for data engineering category 7.

# %% [markdown]
# ### Answer
# Key explanation for question 17. Include architecture reasoning and tradeoffs. At Citi scale, this matters due to regulatory + volume constraints.
#
# **Rubric:**
# - key concept
# - tradeoff
# - scaling implication

# %% [markdown]
# ### Question 18
# Explain a Staff-level concept for data engineering category 8.

# %% [markdown]
# ### Answer
# Key explanation for question 18. Include architecture reasoning and tradeoffs. At Citi scale, this matters due to regulatory + volume constraints.
#
# **Rubric:**
# - key concept
# - tradeoff
# - scaling implication

# %% [markdown]
# ### Question 19
# Explain a Staff-level concept for data engineering category 9.

# %% [markdown]
# ### Answer
# Key explanation for question 19. Include architecture reasoning and tradeoffs. At Citi scale, this matters due to regulatory + volume constraints.
#
# **Rubric:**
# - key concept
# - tradeoff
# - scaling implication

# %% [markdown]
# ### Question 20
# Explain a Staff-level concept for data engineering category 10.

# %% [markdown]
# ### Answer
# Key explanation for question 20. Include architecture reasoning and tradeoffs. At Citi scale, this matters due to regulatory + volume constraints.
#
# **Rubric:**
# - key concept
# - tradeoff
# - scaling implication

# %% [markdown]
# ### Question 21
# Explain a Staff-level concept for data engineering category 11.

# %% [markdown]
# ### Answer
# Key explanation for question 21. Include architecture reasoning and tradeoffs. At Citi scale, this matters due to regulatory + volume constraints.
#
# **Rubric:**
# - key concept
# - tradeoff
# - scaling implication

# %% [markdown]
# ### Question 22
# Explain a Staff-level concept for data engineering category 1.

# %% [markdown]
# ### Answer
# Key explanation for question 22. Include architecture reasoning and tradeoffs. At Citi scale, this matters due to regulatory + volume constraints.
#
# **Rubric:**
# - key concept
# - tradeoff
# - scaling implication

# %% [markdown]
# ### Question 23
# Explain a Staff-level concept for data engineering category 2.

# %% [markdown]
# ### Answer
# Key explanation for question 23. Include architecture reasoning and tradeoffs. At Citi scale, this matters due to regulatory + volume constraints.
#
# **Rubric:**
# - key concept
# - tradeoff
# - scaling implication

# %% [markdown]
# ### Question 24
# Explain a Staff-level concept for data engineering category 3.

# %% [markdown]
# ### Answer
# Key explanation for question 24. Include architecture reasoning and tradeoffs. At Citi scale, this matters due to regulatory + volume constraints.
#
# **Rubric:**
# - key concept
# - tradeoff
# - scaling implication

# %% [markdown]
# ### Question 25
# Explain a Staff-level concept for data engineering category 4.

# %% [markdown]
# ### Answer
# Key explanation for question 25. Include architecture reasoning and tradeoffs. At Citi scale, this matters due to regulatory + volume constraints.
#
# **Rubric:**
# - key concept
# - tradeoff
# - scaling implication

# %% [markdown]
# ### Question 26
# Explain a Staff-level concept for data engineering category 5.

# %% [markdown]
# ### Answer
# Key explanation for question 26. Include architecture reasoning and tradeoffs. At Citi scale, this matters due to regulatory + volume constraints.
#
# **Rubric:**
# - key concept
# - tradeoff
# - scaling implication

# %% [markdown]
# ### Question 27
# Explain a Staff-level concept for data engineering category 6.

# %% [markdown]
# ### Answer
# Key explanation for question 27. Include architecture reasoning and tradeoffs. At Citi scale, this matters due to regulatory + volume constraints.
#
# **Rubric:**
# - key concept
# - tradeoff
# - scaling implication

# %% [markdown]
# ### Question 28
# Explain a Staff-level concept for data engineering category 7.

# %% [markdown]
# ### Answer
# Key explanation for question 28. Include architecture reasoning and tradeoffs. At Citi scale, this matters due to regulatory + volume constraints.
#
# **Rubric:**
# - key concept
# - tradeoff
# - scaling implication

# %% [markdown]
# ### Question 29
# Explain a Staff-level concept for data engineering category 8.

# %% [markdown]
# ### Answer
# Key explanation for question 29. Include architecture reasoning and tradeoffs. At Citi scale, this matters due to regulatory + volume constraints.
#
# **Rubric:**
# - key concept
# - tradeoff
# - scaling implication

# %% [markdown]
# ### Question 30
# Explain a Staff-level concept for data engineering category 9.

# %% [markdown]
# ### Answer
# Key explanation for question 30. Include architecture reasoning and tradeoffs. At Citi scale, this matters due to regulatory + volume constraints.
#
# **Rubric:**
# - key concept
# - tradeoff
# - scaling implication

# %% [markdown]
# ### Question 31
# Explain a Staff-level concept for data engineering category 10.

# %% [markdown]
# ### Answer
# Key explanation for question 31. Include architecture reasoning and tradeoffs. At Citi scale, this matters due to regulatory + volume constraints.
#
# **Rubric:**
# - key concept
# - tradeoff
# - scaling implication

# %% [markdown]
# ### Question 32
# Explain a Staff-level concept for data engineering category 11.

# %% [markdown]
# ### Answer
# Key explanation for question 32. Include architecture reasoning and tradeoffs. At Citi scale, this matters due to regulatory + volume constraints.
#
# **Rubric:**
# - key concept
# - tradeoff
# - scaling implication

# %% [markdown]
# ### Question 33
# Explain a Staff-level concept for data engineering category 1.

# %% [markdown]
# ### Answer
# Key explanation for question 33. Include architecture reasoning and tradeoffs. At Citi scale, this matters due to regulatory + volume constraints.
#
# **Rubric:**
# - key concept
# - tradeoff
# - scaling implication

# %% [markdown]
# ### Question 34
# Explain a Staff-level concept for data engineering category 2.

# %% [markdown]
# ### Answer
# Key explanation for question 34. Include architecture reasoning and tradeoffs. At Citi scale, this matters due to regulatory + volume constraints.
#
# **Rubric:**
# - key concept
# - tradeoff
# - scaling implication

# %% [markdown]
# ### Question 35
# Explain a Staff-level concept for data engineering category 3.

# %% [markdown]
# ### Answer
# Key explanation for question 35. Include architecture reasoning and tradeoffs. At Citi scale, this matters due to regulatory + volume constraints.
#
# **Rubric:**
# - key concept
# - tradeoff
# - scaling implication

# %% [markdown]
# ### Question 36
# Explain a Staff-level concept for data engineering category 4.

# %% [markdown]
# ### Answer
# Key explanation for question 36. Include architecture reasoning and tradeoffs. At Citi scale, this matters due to regulatory + volume constraints.
#
# **Rubric:**
# - key concept
# - tradeoff
# - scaling implication

# %% [markdown]
# ### Question 37
# Explain a Staff-level concept for data engineering category 5.

# %% [markdown]
# ### Answer
# Key explanation for question 37. Include architecture reasoning and tradeoffs. At Citi scale, this matters due to regulatory + volume constraints.
#
# **Rubric:**
# - key concept
# - tradeoff
# - scaling implication

# %% [markdown]
# ### Question 38
# Explain a Staff-level concept for data engineering category 6.

# %% [markdown]
# ### Answer
# Key explanation for question 38. Include architecture reasoning and tradeoffs. At Citi scale, this matters due to regulatory + volume constraints.
#
# **Rubric:**
# - key concept
# - tradeoff
# - scaling implication

# %% [markdown]
# ### Question 39
# Explain a Staff-level concept for data engineering category 7.

# %% [markdown]
# ### Answer
# Key explanation for question 39. Include architecture reasoning and tradeoffs. At Citi scale, this matters due to regulatory + volume constraints.
#
# **Rubric:**
# - key concept
# - tradeoff
# - scaling implication

# %% [markdown]
# ### Question 40
# Explain a Staff-level concept for data engineering category 8.

# %% [markdown]
# ### Answer
# Key explanation for question 40. Include architecture reasoning and tradeoffs. At Citi scale, this matters due to regulatory + volume constraints.
#
# **Rubric:**
# - key concept
# - tradeoff
# - scaling implication

# %% [markdown]
# ### Question 41
# Explain a Staff-level concept for data engineering category 9.

# %% [markdown]
# ### Answer
# Key explanation for question 41. Include architecture reasoning and tradeoffs. At Citi scale, this matters due to regulatory + volume constraints.
#
# **Rubric:**
# - key concept
# - tradeoff
# - scaling implication

# %% [markdown]
# ### Question 42
# Explain a Staff-level concept for data engineering category 10.

# %% [markdown]
# ### Answer
# Key explanation for question 42. Include architecture reasoning and tradeoffs. At Citi scale, this matters due to regulatory + volume constraints.
#
# **Rubric:**
# - key concept
# - tradeoff
# - scaling implication

# %% [markdown]
# ### Question 43
# Explain a Staff-level concept for data engineering category 11.

# %% [markdown]
# ### Answer
# Key explanation for question 43. Include architecture reasoning and tradeoffs. At Citi scale, this matters due to regulatory + volume constraints.
#
# **Rubric:**
# - key concept
# - tradeoff
# - scaling implication

# %% [markdown]
# ### Question 44
# Explain a Staff-level concept for data engineering category 1.

# %% [markdown]
# ### Answer
# Key explanation for question 44. Include architecture reasoning and tradeoffs. At Citi scale, this matters due to regulatory + volume constraints.
#
# **Rubric:**
# - key concept
# - tradeoff
# - scaling implication

# %% [markdown]
# ### Question 45
# Explain a Staff-level concept for data engineering category 2.

# %% [markdown]
# ### Answer
# Key explanation for question 45. Include architecture reasoning and tradeoffs. At Citi scale, this matters due to regulatory + volume constraints.
#
# **Rubric:**
# - key concept
# - tradeoff
# - scaling implication

# %% [markdown]
# ### Question 46
# Explain a Staff-level concept for data engineering category 3.

# %% [markdown]
# ### Answer
# Key explanation for question 46. Include architecture reasoning and tradeoffs. At Citi scale, this matters due to regulatory + volume constraints.
#
# **Rubric:**
# - key concept
# - tradeoff
# - scaling implication

# %% [markdown]
# ### Question 47
# Explain a Staff-level concept for data engineering category 4.

# %% [markdown]
# ### Answer
# Key explanation for question 47. Include architecture reasoning and tradeoffs. At Citi scale, this matters due to regulatory + volume constraints.
#
# **Rubric:**
# - key concept
# - tradeoff
# - scaling implication

# %% [markdown]
# ### Question 48
# Explain a Staff-level concept for data engineering category 5.

# %% [markdown]
# ### Answer
# Key explanation for question 48. Include architecture reasoning and tradeoffs. At Citi scale, this matters due to regulatory + volume constraints.
#
# **Rubric:**
# - key concept
# - tradeoff
# - scaling implication

# %% [markdown]
# ### Question 49
# Explain a Staff-level concept for data engineering category 6.

# %% [markdown]
# ### Answer
# Key explanation for question 49. Include architecture reasoning and tradeoffs. At Citi scale, this matters due to regulatory + volume constraints.
#
# **Rubric:**
# - key concept
# - tradeoff
# - scaling implication

# %% [markdown]
# ### Question 50
# Explain a Staff-level concept for data engineering category 7.

# %% [markdown]
# ### Answer
# Key explanation for question 50. Include architecture reasoning and tradeoffs. At Citi scale, this matters due to regulatory + volume constraints.
#
# **Rubric:**
# - key concept
# - tradeoff
# - scaling implication

# %% [markdown]
# ### Question 51
# Explain a Staff-level concept for data engineering category 8.

# %% [markdown]
# ### Answer
# Key explanation for question 51. Include architecture reasoning and tradeoffs. At Citi scale, this matters due to regulatory + volume constraints.
#
# **Rubric:**
# - key concept
# - tradeoff
# - scaling implication

# %% [markdown]
# ### Question 52
# Explain a Staff-level concept for data engineering category 9.

# %% [markdown]
# ### Answer
# Key explanation for question 52. Include architecture reasoning and tradeoffs. At Citi scale, this matters due to regulatory + volume constraints.
#
# **Rubric:**
# - key concept
# - tradeoff
# - scaling implication

# %% [markdown]
# ### Question 53
# Explain a Staff-level concept for data engineering category 10.

# %% [markdown]
# ### Answer
# Key explanation for question 53. Include architecture reasoning and tradeoffs. At Citi scale, this matters due to regulatory + volume constraints.
#
# **Rubric:**
# - key concept
# - tradeoff
# - scaling implication

# %% [markdown]
# ### Question 54
# Explain a Staff-level concept for data engineering category 11.

# %% [markdown]
# ### Answer
# Key explanation for question 54. Include architecture reasoning and tradeoffs. At Citi scale, this matters due to regulatory + volume constraints.
#
# **Rubric:**
# - key concept
# - tradeoff
# - scaling implication

# %% [markdown]
# ### Question 55
# Explain a Staff-level concept for data engineering category 1.

# %% [markdown]
# ### Answer
# Key explanation for question 55. Include architecture reasoning and tradeoffs. At Citi scale, this matters due to regulatory + volume constraints.
#
# **Rubric:**
# - key concept
# - tradeoff
# - scaling implication

# %% [markdown]
# ### Question 56
# Explain a Staff-level concept for data engineering category 2.

# %% [markdown]
# ### Answer
# Key explanation for question 56. Include architecture reasoning and tradeoffs. At Citi scale, this matters due to regulatory + volume constraints.
#
# **Rubric:**
# - key concept
# - tradeoff
# - scaling implication

# %% [markdown]
# ### Question 57
# Explain a Staff-level concept for data engineering category 3.

# %% [markdown]
# ### Answer
# Key explanation for question 57. Include architecture reasoning and tradeoffs. At Citi scale, this matters due to regulatory + volume constraints.
#
# **Rubric:**
# - key concept
# - tradeoff
# - scaling implication

# %% [markdown]
# ### Question 58
# Explain a Staff-level concept for data engineering category 4.

# %% [markdown]
# ### Answer
# Key explanation for question 58. Include architecture reasoning and tradeoffs. At Citi scale, this matters due to regulatory + volume constraints.
#
# **Rubric:**
# - key concept
# - tradeoff
# - scaling implication

# %% [markdown]
# ### Question 59
# Explain a Staff-level concept for data engineering category 5.

# %% [markdown]
# ### Answer
# Key explanation for question 59. Include architecture reasoning and tradeoffs. At Citi scale, this matters due to regulatory + volume constraints.
#
# **Rubric:**
# - key concept
# - tradeoff
# - scaling implication

# %% [markdown]
# ### Question 60
# Explain a Staff-level concept for data engineering category 6.

# %% [markdown]
# ### Answer
# Key explanation for question 60. Include architecture reasoning and tradeoffs. At Citi scale, this matters due to regulatory + volume constraints.
#
# **Rubric:**
# - key concept
# - tradeoff
# - scaling implication

# %%
# Non-interactive execution — simulate 45/60 passing score
score=45
pct=score/60*100
print(f"Score: {pct}%")
print("PASS" if score>=45 else "FAIL")
# Out:
# Score: 75.0%
# PASS

# %% [markdown]
# ## Debrief
# Review weak areas; focus on system design and tradeoffs.
