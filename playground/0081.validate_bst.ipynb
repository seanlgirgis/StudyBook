# %% [markdown]
# ## Validate Binary Search Tree
#
# Given the root of a binary tree, determine if it is a valid **Binary Search Tree (BST)**.
#
# A valid BST satisfies:
# - The left subtree of a node contains only nodes with keys **less than** the node's key.
# - The right subtree of a node contains only nodes with keys **greater than** the node's key.
# - Both the left and right subtrees must also be valid BSTs.
#
# **Note:** You are not expected to provide the most optimal solution, but a solution with time complexity not worse than **O(n)** will fit within the execution time limit.
#
# ### Example
#
# ```
# Valid BST:       Invalid BST:
#     2                5
#    / \              / \
#   1   3            1   4
#                       / \
#                       3   6
# ```
# The second tree is invalid because 4 is in the right subtree of 5 but 4 < 5.
#
# ### Input/Output
#
# - **[execution time limit]** 4 seconds (py3)
# - **[input]** `TreeNode` `root`
# - **[output]** `boolean`

# %%
# %run _timer.py
# Out:
# <div style="font-family:monospace;background:#1e1e1e;color:#d4d4d4;
#             border-radius:8px;padding:14px;width:320px;user-select:none;">
#   <div id="td-tldvrs" style="font-size:2.4em;text-align:center;
#                              letter-spacing:4px;padding:8px 0;">00:00</div>
#   <div style="display:flex;gap:8px;justify-content:center;margin-top:8px;">
#     <button id="btn-start-tldvrs"
#       style="background:#0e639c;color:#fff;border:none;border-radius:4px;
#              padding:6px 16px;cursor:pointer;font-family:monospace;">Start</button>
#     <button id="btn-stop-tldvrs"
#       style="background:#5a5a5a;color:#fff;border:none;border-radius:4px;
#              padding:6px 16px;cursor:pointer;font-family:monospace;">Stop</button>
#     <button id="btn-reset-tldvrs"
#       style="background:#5a5a5a;color:#fff;border:none;border-radius:4px;
#              padding:6px 16px;cursor:pointer;font-family:monospace;">Reset</button>
#     <button id="btn-copy-tldvrs"
# ...

# %%
# O(n) alternative — pass (lo, hi) bounds down; each node visited exactly once
#
# At each node, check: lo < node.val < hi
# Going left:  upper bound tightens to node.val
# Going right: lower bound tightens to node.val
# Start with (-inf, +inf) at root — no constraints yet
from collections import deque

class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val   = val
        self.left  = left
        self.right = right

def make_tree(vals):
    if not vals or vals[0] is None:
        return None
    root = TreeNode(vals[0])
    queue = deque([root])
    i = 1
    while queue and i < len(vals):
        node = queue.popleft()
        if i < len(vals) and vals[i] is not None:
            node.left = TreeNode(vals[i])
            queue.append(node.left)
        i += 1
        if i < len(vals) and vals[i] is not None:
            node.right = TreeNode(vals[i])
            queue.append(node.right)
        i += 1
    return root

def is_valid(node, lo, hi):
    if not node: return True
    if not (lo < node.val < hi): return False
    return is_valid(node.left, lo, node.val) and is_valid(node.right, node.val, hi)

def solution_on(root):
    return is_valid(root, float('-inf'), float('inf'))


assert solution_on(make_tree([2,1,3]))                  == True
assert solution_on(make_tree([5,1,4,None,None,3,6]))    == False
assert solution_on(None)                                == True
assert solution_on(make_tree([1]))                      == True
assert solution_on(make_tree([5,3,7,2,4,6,8]))          == True
assert solution_on(make_tree([5,3,7,2,6,4,8]))          == False
assert solution_on(make_tree([10,5,15,None,None,6,20])) == False
assert solution_on(make_tree([3,1,5,None,None,4,6]))    == True
print('O(n) solution — All Pass!')
# Out:
# O(n) solution — All Pass!
