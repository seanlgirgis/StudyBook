# %% [markdown]
# # Python Mastery Index
# This is the frozen index for mastery review notebooks in this folder.
# ## Naming Convention
# - Format: python_mastery_NN_topic.ipynb- Sequence: NN is two digits and defines review order.
# - Topic: lowercase snake_case.
# ## Notebook List
# - [python_mastery_01_hashmaps_sets.ipynb](python_mastery_01_hashmaps_sets.ipynb)
# - [python_mastery_02_grids_boundaries.ipynb](python_mastery_02_grids_boundaries.ipynb)
# - [python_mastery_03_sorting_keys.ipynb](python_mastery_03_sorting_keys.ipynb)
# - [python_mastery_04_prefix_sums.ipynb](python_mastery_04_prefix_sums.ipynb)
# - [python_mastery_05_sliding_window.ipynb](python_mastery_05_sliding_window.ipynb)
# ## Source Notebook
# - [Python.Mastrey1.ipynb](Python.Mastrey1.ipynb)

# %%
# Optional quick check: run to list mastery notebooks in this folder
from pathlib import Path
p = Path('.')
for n in sorted(p.glob('python_mastery_*.ipynb')):
    print(n.name)
