# %% [markdown]
# # LC 974 - Subarray Sums Divisible by K
#
# > Description: LeetCode 974 placeholder notebook for prefix-mod frequency counting.
#
# Use this notebook for your solution + tests in your standard format.

# %%
"""
id: lc_0974
title: Subarray Sums Divisible by K
source: leetcode
difficulty: medium
primary: hash table
tags: [array, hash-table, prefix-sum]
leetcode_url: https://leetcode.com/problems/subarray-sums-divisible-by-k/
status: draft
last_updated: 2026-04-23
notes:
- key idea: prefix sum modulo k with frequency tracking
- time: O(n)
- space: O(k)
"""

# ============================================================================
# File: 974_lc_0974_subarray_sums_divisible_by_k_empty.py
# LeetCode 974: Subarray Sums Divisible by K
# Difficulty: Medium
#
# PROBLEM STATEMENT:
# Given an integer array nums and an integer k, return the number of non-empty 
# subarrays that have a sum divisible by k.
#
# RULES:
# - A subarray is a contiguous part of an array.
# - Negative remainders should be handled (sum % k + k) % k.
#
# EXAMPLES:
# Input: nums = [4,5,0,-2,-3,1], k = 5
# Output: 7
# Explanation: [4, 5, 0, -2, -3, 1], [5], [5, 0], [5, 0, -2, -3], [0], [0, -2, -3], [-2, -3]
# ============================================================================

from typing import List

def subarraysDivByK(nums: List[int], k: int) -> int:
    # TODO: implement
    pass

print(subarraysDivByK([4,5,0,-2,-3,1], 5))
print(subarraysDivByK([5], 9))

def test():
    assert subarraysDivByK([4,5,0,-2,-3,1], 5) == 7  # example 1
    assert subarraysDivByK([5], 9) == 0               # example 2
    assert subarraysDivByK([-1,2,9], 2) == 2         # negative prefix
    assert subarraysDivByK([2,-2,2,-2], 5) == 2      # zero sums
    assert subarraysDivByK([7,7,7], 7) == 6          # all divisible
    assert subarraysDivByK([1,2,3], 3) == 2          # [1,2] and [3]
    assert subarraysDivByK([0,0,0], 1) == 6          # multiple zeros
    assert subarraysDivByK([-5], 5) == 1             # single negative match
    assert subarraysDivByK([1,1,1], 2) == 1          # simple odd sum
    assert subarraysDivByK([8,9,7,8,9], 8) == 3      # multiple matches
    print('All Pass!')

test()
