# %% [markdown]
# # 📚 Sean's CodeSignal Study Guide
#
# > Capital One GCA — 70 min · 4 questions · Python 3
# > Q1/Q2 warm-up (≤15 min total) · Q3/Q4 medium/hard
# > Key topics: **2D arrays/matrices · HashMaps · DSA**
#
# ---
#
# ## How to use this guide
# - **Click any link** → opens that notebook in a new tab
# - Each section is ordered **easiest → hardest**
# - 🟢 Easy &nbsp;&nbsp; 🟡 Medium &nbsp;&nbsp; 🔴 Hard
# - Work one section at a time. Re-do problems you hesitated on.
#
# ---
#
# ## Quick Jump
# | | Topic | | Topic |
# |---|---|---|---|
# | 00 | [📖 Basics / Cheat Sheets](#basics) | 12 | [Graphs](#graphs) |
# | 01 | [Arrays & Patterns](#arrays) | 13 | [DP — 1D](#dp1d) |
# | 02 | [HashMap / Counter](#hashmap) | 14 | [DP — 2D](#dp2d) |
# | 03 | [Two Pointers](#twoptr) | 15 | [Heap / Priority Queue](#heap) |
# | 04 | [Sliding Window](#sliding) | 16 | [Backtracking](#backtrack) |
# | 05 | [Prefix Sums](#prefix) | 17 | [Intervals](#intervals) |
# | 06 | [Binary Search](#binsearch) | 18 | [Bit Manipulation](#bits) |
# | 07 | [Stack](#stack) | 19 | [Greedy](#greedy) |
# | 08 | [Monotonic Stack](#monostack) | 20 | [String](#string) |
# | 09 | [2D Matrix](#matrix) | 21 | [Simulation](#simulation) |
# | 10 | [Linked Lists](#linked) | 22 | [🔴 Hard Classics](#hard) |
# | 11 | [Trees](#trees) | | |

# %% [markdown]
# ---
# <a id="basics"></a>
# ## 📖 00 — Basics / Cheat Sheets
#
# > Start here before drilling a topic. These are reference sheets, not problems.
#
# | File | What's inside |
# |------|---------------|
# | [linked_list_basics.ipynb](Basics/linked_list_basics.ipynb) | Node class, reverse, dummy head, fast/slow pointer |
# | [binary_tree_basics.ipynb](Basics/binary_tree_basics.ipynb) | TreeNode class, DFS/BFS templates, inorder/preorder/postorder |
# | [monotonic_stack_basics.ipynb](Basics/monotonic_stack_basics.ipynb) | Decreasing vs increasing stack, next/prev greater/smaller templates |

# %% [markdown]
# ---
# <a id="arrays"></a>
# ## 01 — Arrays & Patterns
#
# | # | File | Difficulty | Key idea |
# |---|------|------------|----------|
# | 0019 | [running_sum.ipynb](0019.running_sum.ipynb) | 🟢 | `accumulate` / prefix sum |
# | 0045 | [find_disappeared.ipynb](0045.find_disappeared.ipynb) | 🟢 | Set difference, range vs array |
# | 0046 | [majority_element.ipynb](0046.majority_element.ipynb) | 🟢 | Counter + Boyer-Moore |
# | 0091 | [move_zeroes.ipynb](0091.move_zeroes.ipynb) | 🟢 | Two-pointer insert pointer |
# | 0099 | [find_peak_element.ipynb](0099.find_peak_element.ipynb) | 🟢 | Max = peak (linear) |
# | 0003 | [zigzag.ipynb](0003.zigzag.ipynb) | 🟢 | Peak/valley detection |
# | 0017 | [max_subarray.ipynb](0017.max_subarray.ipynb) | 🟡 | Kadane's — extend or restart |
# | 0021 | [min_subarray.ipynb](0021.min_subarray.ipynb) | 🟡 | Kadane's flipped |
# | 0023 | [product_except_self.ipynb](0023.product_except_self.ipynb) | 🟡 | Prefix × suffix, no division |
# | 0067 | [jump_game.ipynb](0067.jump_game.ipynb) | 🟡 | Greedy max_reach |
# | 0047 | [best_time_stock.ipynb](0047.best_time_stock.ipynb) | 🟢 | Running min + max profit |

# %% [markdown]
# ---
# <a id="hashmap"></a>
# ## 02 — HashMap / Counter
#
# | # | File | Difficulty | Key idea |
# |---|------|------------|----------|
# | 0012 | [first_unique.ipynb](0012.first_unique.ipynb) | 🟢 | Two-pass Counter |
# | 0018 | [valid_anagram.ipynb](0018.valid_anagram.ipynb) | 🟢 | Fixed array [26] vs Counter |
# | 0063 | [ransom_note.ipynb](0063.ransom_note.ipynb) | 🟢 | Counter — `mag[c] < freq` |
# | 0046 | [majority_element.ipynb](0046.majority_element.ipynb) | 🟢 | `most_common(1)[0][0]` |
# | 0014 | [two_sum.ipynb](0014.two_sum.ipynb) | 🟢 | Complement dict — O(n) |
# | 0022 | [most_frequent.ipynb](0022.most_frequent.ipynb) | 🟡 | `(-freq, num)` tuple trick |
# | 0029 | [group_anagrams.ipynb](0029.group_anagrams.ipynb) | 🟡 | Freq array as dict key |
# | 0037 | [longest_consecutive.ipynb](0037.longest_consecutive.ipynb) | 🟡 | Set — start of streak only |
# | 0035 | [subarray_sum_k.ipynb](0035.subarray_sum_k.ipynb) | 🟡 | Prefix sum + HashMap, query before store |
# | 0036 | [top_k_frequent.ipynb](0036.top_k_frequent.ipynb) | 🟡 | Size-k min-heap with Counter |
# | 0076 | [valid_sudoku.ipynb](0076.valid_sudoku.ipynb) | 🟡 | Sets per row/col/box |

# %% [markdown]
# ---
# <a id="twoptr"></a>
# ## 03 — Two Pointers
#
# | # | File | Difficulty | Key idea |
# |---|------|------------|----------|
# | 0024 | [sorted_squares.ipynb](0024.sorted_squares.ipynb) | 🟢 | Outward pointers, fill from back |
# | 0025 | [is_palindrome.ipynb](0025.is_palindrome.ipynb) | 🟢 | Inward closing pointers |
# | 0026 | [merge_sorted.ipynb](0026.merge_sorted.ipynb) | 🟢 | Advance the smaller pointer |
# | 0091 | [move_zeroes.ipynb](0091.move_zeroes.ipynb) | 🟢 | Insert pointer |
# | 0097 | [reverse_string.ipynb](0097.reverse_string.ipynb) | 🟢 | Swap l, r inward |
# | 0098 | [valid_palindrome.ipynb](0098.valid_palindrome.ipynb) | 🟢 | Skip non-alnum, `isalnum()` |
# | 0128 | [two_sum_ii_sorted.ipynb](0128.two_sum_ii_sorted.ipynb) | 🟡 | l++/r-- based on sum vs target |
# | 0039 | [container_water.ipynb](0039.container_water.ipynb) | 🟡 | Advance shorter wall |
# | 0038 | [three_sum.ipynb](0038.three_sum.ipynb) | 🟡 | Sort + two-pointer inner loop |
# | 0074 | [longest_palindrome_substr.ipynb](0074.longest_palindrome_substr.ipynb) | 🟡 | Expand from center, odd+even |
# | 0144 | [trapping_rain_water.ipynb](0144.trapping_rain_water.ipynb) | 🔴 | Move shorter side — `min(max_l, max_r) - h[i]` |

# %% [markdown]
# ---
# <a id="sliding"></a>
# ## 04 — Sliding Window
#
# | # | File | Difficulty | Key idea |
# |---|------|------------|----------|
# | 0020 | [max_window_sum.ipynb](0020.max_window_sum.ipynb) | 🟢 | Fixed window — `range(k, n+1)` |
# | 0061 | [longest_subarray_ones.ipynb](0061.longest_subarray_ones.ipynb) | 🟡 | At most one 0 — `right-left` (no +1) |
# | 0062 | [max_consecutive_ones.ipynb](0062.max_consecutive_ones.ipynb) | 🟡 | At most k zeros — `right-left+1` |
# | 0030 | [longest_unique.ipynb](0030.longest_unique.ipynb) | 🟡 | Variable window, shrink while dupe |
# | 0073 | [find_anagrams.ipynb](0073.find_anagrams.ipynb) | 🟡 | Fixed window, [26] compare |
# | 0122 | [longest_repeating_char_replacement.ipynb](0122.longest_repeating_char_replacement.ipynb) | 🟡 | window − max_freq > k → shrink |
# | 0148 | [minimum_window_substring.ipynb](0148.minimum_window_substring.ipynb) | 🔴 | `have/required` counter; expand r, shrink l |

# %% [markdown]
# ---
# <a id="prefix"></a>
# ## 05 — Prefix Sums
#
# | # | File | Difficulty | Key idea |
# |---|------|------------|----------|
# | 0019 | [running_sum.ipynb](0019.running_sum.ipynb) | 🟢 | `accumulate` / iterative build |
# | 0069 | [pivot_index.ipynb](0069.pivot_index.ipynb) | 🟢 | `right = total − left − nums[i]` |
# | 0023 | [product_except_self.ipynb](0023.product_except_self.ipynb) | 🟡 | Prefix × suffix in-place |
# | 0035 | [subarray_sum_k.ipynb](0035.subarray_sum_k.ipynb) | 🟡 | Prefix + HashMap — query before store |

# %% [markdown]
# ---
# <a id="binsearch"></a>
# ## 06 — Binary Search
#
# | # | File | Difficulty | Key idea |
# |---|------|------------|----------|
# | 0027 | [binary_search.ipynb](0027.binary_search.ipynb) | 🟢 | `mid = (l+r)//2`, return l |
# | 0028 | [search_insert.ipynb](0028.search_insert.ipynb) | 🟢 | l lands at insertion point |
# | 0099 | [find_peak_element.ipynb](0099.find_peak_element.ipynb) | 🟢 | `max()` — linear is fine |
# | 0075 | [search_2d_matrix.ipynb](0075.search_2d_matrix.ipynb) | 🟡 | Flat index: `row=mid//n, col=mid%n` |
# | 0105 | [find_min_rotated.ipynb](0105.find_min_rotated.ipynb) | 🟡 | `nums[mid]>nums[r]` → `l=mid+1` |
# | 0106 | [find_pivot_rotated.ipynb](0106.find_pivot_rotated.ipynb) | 🟡 | Same as above — return l (index) |
# | 0121 | [search_rotated_sorted_array.ipynb](0121.search_rotated_sorted_array.ipynb) | 🟡 | Identify sorted half, target in range? |

# %% [markdown]
# ---
# <a id="stack"></a>
# ## 07 — Stack
#
# | # | File | Difficulty | Key idea |
# |---|------|------------|----------|
# | 0031 | [valid_parentheses.ipynb](0031.valid_parentheses.ipynb) | 🟢 | Push open, match close |
# | 0032 | [min_stack.ipynb](0032.min_stack.ipynb) | 🟡 | `(val, min_so_far)` tuple |
# | 0112 | [evaluate_rpn.ipynb](0112.evaluate_rpn.ipynb) | 🟡 | Pop b, a → `a op b`, `int(a/b)` |
# | 0070 | [decode_string.ipynb](0070.decode_string.ipynb) | 🟡 | Push all, pop alpha+`[`+digits on `]` |

# %% [markdown]
# ---
# <a id="monostack"></a>
# ## 08 — Monotonic Stack
#
# > 📖 Review [monotonic_stack_basics.ipynb](Basics/monotonic_stack_basics.ipynb) first!
#
# | # | File | Difficulty | Key idea |
# |---|------|------------|----------|
# | 0109 | [final_prices_discount.ipynb](0109.final_prices_discount.ipynb) | 🟢 | Next smaller-or-equal, copy input |
# | 0101 | [daily_temperatures.ipynb](0101.daily_temperatures.ipynb) | 🟡 | Store indices, `ans[idx] = i − idx` |
# | 0103 | [next_greater_element_single_list.ipynb](0103.next_greater_element_single_list.ipynb) | 🟡 | Stack of indices, write on pop |
# | 0107 | [next_smaller_element.ipynb](0107.next_smaller_element.ipynb) | 🟡 | Increasing stack — val < top to pop |
# | 0108 | [previous_greater_element.ipynb](0108.previous_greater_element.ipynb) | 🟡 | Right-to-left scan |
# | 0102 | [next_greater_element.ipynb](0102.next_greater_element.ipynb) | 🟡 | Two lists — lookup map value→index |
# | 0104 | [next_greater_element_circular.ipynb](0104.next_greater_element_circular.ipynb) | 🟡 | `range(2*n), i%n`, push only if `i<n` |
# | 0110 | [online_stock_span.ipynb](0110.online_stock_span.ipynb) | 🟡 | `(price, span)` tuples, absorb spans on pop |
# | 0111 | [car_fleet.ipynb](0111.car_fleet.ipynb) | 🟡 | Sort by dist, push if new fleet |
# | 0113 | [next_greater_node_linked_list.ipynb](0113.next_greater_node_linked_list.ipynb) | 🟡 | Flatten list → NGE stack |
# | 0143 | [largest_rectangle_histogram.ipynb](0143.largest_rectangle_histogram.ipynb) | 🔴 | `(start, height)` tuples — pop when shorter bar arrives |

# %% [markdown]
# ---
# <a id="matrix"></a>
# ## 09 — 2D Matrix
#
# | # | File | Difficulty | Key idea |
# |---|------|------------|----------|
# | 0011 | [diagonal_difference.ipynb](0011.diagonal_difference.ipynb) | 🟢 | Primary vs secondary diagonal |
# | 0013 | [border_sum.ipynb](0013.border_sum.ipynb) | 🟢 | Set union of 4 edges |
# | 0015 | [column_sums.ipynb](0015.column_sums.ipynb) | 🟢 | `zip(*matrix)` |
# | 0016 | [transpose.ipynb](0016.transpose.ipynb) | 🟢 | `[list(col) for col in zip(*m)]` |
# | 0066 | [matrix_zero.ipynb](0066.matrix_zero.ipynb) | 🟡 | Collect positions first, then zero |
# | 0033 | [matrix_rotation.ipynb](0033.matrix_rotation.ipynb) | 🟡 | Transpose + reverse rows |
# | 0034 | [spiral_order.ipynb](0034.spiral_order.ipynb) | 🟡 | Pop top row, rotate CCW, repeat |
# | 0076 | [valid_sudoku.ipynb](0076.valid_sudoku.ipynb) | 🟡 | Sets per row/col/sub-box |
# | 0114 | [unique_paths_ii.ipynb](0114.unique_paths_ii.ipynb) | 🟡 | 2D DP, obstacle zeros the cell |

# %% [markdown]
# ---
# <a id="grid"></a>
# ## 09b — Grid DFS / BFS
#
# | # | File | Difficulty | Key idea |
# |---|------|------------|----------|
# | 0056 | [flood_fill.ipynb](0056.flood_fill.ipynb) | 🟢 | Same-color early return |
# | 0054 | [number_of_islands.ipynb](0054.number_of_islands.ipynb) | 🟡 | Sink visited land to '0' |
# | 0055 | [max_area_island.ipynb](0055.max_area_island.ipynb) | 🟡 | DFS returns area count |
# | 0057 | [rotting_oranges.ipynb](0057.rotting_oranges.ipynb) | 🟡 | Multi-source BFS with timestamp |
# | 0058 | [word_search.ipynb](0058.word_search.ipynb) | 🟡 | DFS backtracking + path set |

# %% [markdown]
# ---
# <a id="linked"></a>
# ## 10 — Linked Lists
#
# > 📖 Review [linked_list_basics.ipynb](Basics/linked_list_basics.ipynb) first!
#
# | # | File | Difficulty | Key idea |
# |---|------|------------|----------|
# | 0048 | [linked_list_reverse.ipynb](0048.linked_list_reverse.ipynb) | 🟢 | prev/curr/nxt three-pointer |
# | 0049 | [middle_linked_list.ipynb](0049.middle_linked_list.ipynb) | 🟢 | Two-pass count, or slow/fast |
# | 0050 | [linked_list_cycle.ipynb](0050.linked_list_cycle.ipynb) | 🟢 | `id(node)` seen set; Floyd bonus |
# | 0053 | [palindrome_linked_list.ipynb](0053.palindrome_linked_list.ipynb) | 🟢 | Collect vals, `vals == vals[::-1]` |
# | 0051 | [merge_two_sorted_lists.ipynb](0051.merge_two_sorted_lists.ipynb) | 🟢 | Dummy + tail, flush remainder |
# | 0052 | [remove_nth_from_end.ipynb](0052.remove_nth_from_end.ipynb) | 🟡 | Two-pass: length − n |
# | 0113 | [next_greater_node_linked_list.ipynb](0113.next_greater_node_linked_list.ipynb) | 🟡 | Flatten → NGE stack |
# | 0126 | [reorder_list.ipynb](0126.reorder_list.ipynb) | 🟡 | Find mid → reverse half → interleave |

# %% [markdown]
# ---
# <a id="trees"></a>
# ## 11 — Trees
#
# > 📖 Review [binary_tree_basics.ipynb](Basics/binary_tree_basics.ipynb) first!
#
# | # | File | Difficulty | Key idea |
# |---|------|------------|----------|
# | 0077 | [max_depth_binary_tree.ipynb](0077.max_depth_binary_tree.ipynb) | 🟢 | BFS with `(node, depth)` tuples |
# | 0078 | [invert_binary_tree.ipynb](0078.invert_binary_tree.ipynb) | 🟢 | BFS swap, tuple assignment |
# | 0079 | [symmetric_tree.ipynb](0079.symmetric_tree.ipynb) | 🟢 | `is_mirror(l, r)` crossover check |
# | 0083 | [path_sum.ipynb](0083.path_sum.ipynb) | 🟢 | Subtract val down, leaf = remainder==0 |
# | 0087 | [diameter_binary_tree.ipynb](0087.diameter_binary_tree.ipynb) | 🟢 | Post-order: height up, diameter sideways |
# | 0132 | [subtree_of_another_tree.ipynb](0132.subtree_of_another_tree.ipynb) | 🟢 | `same_tree` helper at every node |
# | 0080 | [level_order_traversal.ipynb](0080.level_order_traversal.ipynb) | 🟡 | Snapshot `len(queue)`, inner level loop |
# | 0081 | [validate_bst.ipynb](0081.validate_bst.ipynb) | 🟡 | `is_valid(node, lo, hi)` pass bounds down |
# | 0082 | [lowest_common_ancestor.ipynb](0082.lowest_common_ancestor.ipynb) | 🟡 | BST: both > curr → right, split = answer |
# | 0084 | [count_good_nodes.ipynb](0084.count_good_nodes.ipynb) | 🟡 | DFS with running max, count if val≥max |
# | 0085 | [kth_smallest_bst.ipynb](0085.kth_smallest_bst.ipynb) | 🟡 | Iterative inorder, exit at k==0 |
# | 0086 | [right_side_view.ipynb](0086.right_side_view.ipynb) | 🟡 | Level BFS, append last node per level |
# | 0129 | [lca_binary_tree.ipynb](0129.lca_binary_tree.ipynb) | 🟡 | General tree: both sides non-null → LCA |

# %% [markdown]
# ---
# <a id="graphs"></a>
# ## 12 — Graphs
#
# | # | File | Difficulty | Key idea |
# |---|------|------------|----------|
# | 0093 | [course_schedule.ipynb](0093.course_schedule.ipynb) | 🟡 | 3-state DFS cycle detection |
# | 0130 | [course_schedule_ii.ipynb](0130.course_schedule_ii.ipynb) | 🟡 | Topo sort: append post-order |
# | 0155 | [network_delay_time.ipynb](0155.network_delay_time.ipynb) | 🟡 | Dijkstra — max of all shortest paths |
# | 0154 | [cheapest_flights_k_stops.ipynb](0154.cheapest_flights_k_stops.ipynb) | 🟡 | Bellman-Ford k+1 rounds — snapshot each round |

# %% [markdown]
# ---
# <a id="dp1d"></a>
# ## 13 — Dynamic Programming (1D)
#
# | # | File | Difficulty | Key idea |
# |---|------|------------|----------|
# | 0040 | [climbing_stairs.ipynb](0040.climbing_stairs.ipynb) | 🟢 | Fibonacci two-var rolling |
# | 0072 | [min_cost_climbing.ipynb](0072.min_cost_climbing.ipynb) | 🟢 | Same two-var, `min(prev, prevprev)` |
# | 0100 | [climbing_stairs_variants.ipynb](0100.climbing_stairs_variants.ipynb) | 🟢 | Two-var spaced repeat |
# | 0047 | [best_time_stock.ipynb](0047.best_time_stock.ipynb) | 🟢 | Running min, one-pass |
# | 0041 | [house_robber.ipynb](0041.house_robber.ipynb) | 🟡 | `max(prev1, prev2 + n)` |
# | 0042 | [coin_change.ipynb](0042.coin_change.ipynb) | 🟡 | Bottom-up, `inf` seed |
# | 0123 | [house_robber_ii.ipynb](0123.house_robber_ii.ipynb) | 🟡 | Run rob on `[:-1]` and `[1:]`, take max |
# | 0118 | [longest_increasing_subsequence.ipynb](0118.longest_increasing_subsequence.ipynb) | 🟡 | `dp[i]=max(dp[j]+1)` for all j<i |
# | 0115 | [decode_ways.ipynb](0115.decode_ways.ipynb) | 🟡 | `dp[0]=1` dummy, one-digit + two-digit check |
# | 0116 | [word_break.ipynb](0116.word_break.ipynb) | 🟡 | `dp[0]=True`, `s[j:i]` in word_set |
# | 0117 | [maximum_product_subarray.ipynb](0117.maximum_product_subarray.ipynb) | 🟡 | Track cur_max + cur_min, save old_max |
# | 0137 | [buy_sell_stock_cooldown.ipynb](0137.buy_sell_stock_cooldown.ipynb) | 🟡 | 3 states: held / sold / idle |

# %% [markdown]
# ---
# <a id="dp2d"></a>
# ## 14 — Dynamic Programming (2D)
#
# | # | File | Difficulty | Key idea |
# |---|------|------------|----------|
# | 0043 | [unique_paths.ipynb](0043.unique_paths.ipynb) | 🟡 | `dp[r][c] = dp[r-1][c] + dp[r][c-1]` |
# | 0044 | [min_path_sum.ipynb](0044.min_path_sum.ipynb) | 🟡 | Same grid DP with min |
# | 0114 | [unique_paths_ii.ipynb](0114.unique_paths_ii.ipynb) | 🟡 | Obstacle → zero that cell |
# | 0152 | [longest_common_subsequence.ipynb](0152.longest_common_subsequence.ipynb) | 🟡 | Match → diag+1; else → max(up, left) |
# | 0149 | [edit_distance.ipynb](0149.edit_distance.ipynb) | 🔴 | Match → diag; else → 1+min(diag,up,left) |

# %% [markdown]
# ---
# <a id="heap"></a>
# ## 15 — Heap / Priority Queue
#
# | # | File | Difficulty | Key idea |
# |---|------|------------|----------|
# | 0146 | [last_stone_weight.ipynb](0146.last_stone_weight.ipynb) | 🟢 | Negate → max-heap; pop two, push diff |
# | 0036 | [top_k_frequent.ipynb](0036.top_k_frequent.ipynb) | 🟡 | Size-k min-heap, evict smallest |
# | 0065 | [k_closest_points.ipynb](0065.k_closest_points.ipynb) | 🟡 | Max-heap with `-dist` |
# | 0156 | [kth_largest_stream.ipynb](0156.kth_largest_stream.ipynb) | 🟢 | Min-heap size k — `heap[0]` = kth largest |
# | 0124 | [kth_largest_element.ipynb](0124.kth_largest_element.ipynb) | 🟡 | Min-heap size k (array, not stream) |
# | 0151 | [meeting_rooms_ii.ipynb](0151.meeting_rooms_ii.ipynb) | 🟡 | Sort by start + heap of end times |
# | 0002 | [battery_swap.ipynb](0002.battery_swap.ipynb) | 🟡 | Two heaps: ready + recovering |
# | 0138 | [task_scheduler.ipynb](0138.task_scheduler.ipynb) | 🔴 | Max-heap + cooldown deque |
# | 0150 | [find_median_data_stream.ipynb](0150.find_median_data_stream.ipynb) | 🔴 | Two heaps: lo max-heap + hi min-heap |

# %% [markdown]
# ---
# <a id="backtrack"></a>
# ## 16 — Backtracking
#
# | # | File | Difficulty | Key idea |
# |---|------|------------|----------|
# | 0094 | [subsets.ipynb](0094.subsets.ipynb) | 🟡 | `backtrack(i, path)` — skip or include |
# | 0127 | [permutations.ipynb](0127.permutations.ipynb) | 🟡 | Pick any from remaining, recurse |
# | 0135 | [combination_sum.ipynb](0135.combination_sum.ipynb) | 🟡 | Reuse allowed (pass `i` not `i+1`) |

# %% [markdown]
# ---
# <a id="intervals"></a>
# ## 17 — Intervals
#
# | # | File | Difficulty | Key idea |
# |---|------|------------|----------|
# | 0088 | [merge_intervals.ipynb](0088.merge_intervals.ipynb) | 🟡 | Sort, sweep — overlap → extend end |
# | 0125 | [insert_interval.ipynb](0125.insert_interval.ipynb) | 🟡 | 3 cases: before / overlap / after |
# | 0134 | [non_overlapping_intervals.ipynb](0134.non_overlapping_intervals.ipynb) | 🟡 | Sort by end — greedy keep earliest-ending |

# %% [markdown]
# ---
# <a id="bits"></a>
# ## 18 — Bit Manipulation
#
# | # | File | Difficulty | Key idea |
# |---|------|------------|----------|
# | 0089 | [single_number.ipynb](0089.single_number.ipynb) | 🟢 | XOR — pairs cancel, survivor stays |
# | 0090 | [missing_number.ipynb](0090.missing_number.ipynb) | 🟢 | `n*(n+1)//2 - sum(nums)` |
# | 0096 | [number_of_1_bits.ipynb](0096.number_of_1_bits.ipynb) | 🟢 | `n&1` + right shift; `n&(n-1)` strips LSB |
# | 0092 | [happy_number.ipynb](0092.happy_number.ipynb) | 🟢 | Cycle detection with seen set |
# | 0131 | [counting_bits.ipynb](0131.counting_bits.ipynb) | 🟢 | `dp[i] = dp[i>>1] + (i&1)` |
# | 0147 | [sum_of_two_integers.ipynb](0147.sum_of_two_integers.ipynb) | 🟡 | `a^b` = sum, `(a&b)<<1` = carry; 32-bit mask for Python |

# %% [markdown]
# ---
# <a id="greedy"></a>
# ## 19 — Greedy
#
# | # | File | Difficulty | Key idea |
# |---|------|------------|----------|
# | 0047 | [best_time_stock.ipynb](0047.best_time_stock.ipynb) | 🟢 | Track running min buy price |
# | 0067 | [jump_game.ipynb](0067.jump_game.ipynb) | 🟡 | Track max_reach, abort if `i > max_reach` |
# | 0157 | [hand_of_straights.ipynb](0157.hand_of_straights.ipynb) | 🟡 | Counter + sorted — start each group from smallest card |
# | 0119 | [gas_station.ipynb](0119.gas_station.ipynb) | 🟡 | Sum check + reset start on negative tank |
# | 0136 | [jump_game_ii.ipynb](0136.jump_game_ii.ipynb) | 🟡 | Window `[l, r]` — expand to farthest each jump |

# %% [markdown]
# ---
# <a id="string"></a>
# ## 20 — String
#
# | # | File | Difficulty | Key idea |
# |---|------|------------|----------|
# | 0001 | [key_changes.ipynb](0001.key_changes.ipynb) | 🟢 | `-1` trick, case-insensitive |
# | 0095 | [longest_common_prefix.ipynb](0095.longest_common_prefix.ipynb) | 🟢 | Enumerate first string, check all |
# | 0097 | [reverse_string.ipynb](0097.reverse_string.ipynb) | 🟢 | Two-pointer swap |
# | 0098 | [valid_palindrome.ipynb](0098.valid_palindrome.ipynb) | 🟢 | `isalnum()` + `lower()` |
# | 0018 | [valid_anagram.ipynb](0018.valid_anagram.ipynb) | 🟢 | Fixed array [26] |
# | 0063 | [ransom_note.ipynb](0063.ransom_note.ipynb) | 🟢 | Counter subtraction |
# | 0068 | [string_compression.ipynb](0068.string_compression.ipynb) | 🟢 | Run-length encode, flush at end |
# | 0025 | [is_palindrome.ipynb](0025.is_palindrome.ipynb) | 🟢 | `s[::-1]` one-liner |
# | 0073 | [find_anagrams.ipynb](0073.find_anagrams.ipynb) | 🟡 | Fixed window [26] compare |
# | 0074 | [longest_palindrome_substr.ipynb](0074.longest_palindrome_substr.ipynb) | 🟡 | Expand center, odd + even pivot |
# | 0133 | [palindromic_substrings.ipynb](0133.palindromic_substrings.ipynb) | 🟡 | Same expand, count every valid expansion |
# | 0120 | [encode_decode_strings.ipynb](0120.encode_decode_strings.ipynb) | 🟡 | Length-prefix `"5#hello"` |
# | 0122 | [longest_repeating_char_replacement.ipynb](0122.longest_repeating_char_replacement.ipynb) | 🟡 | Sliding window, `window − max_freq > k` |

# %% [markdown]
# ---
# <a id="simulation"></a>
# ## 21 — Simulation
#
# | # | File | Difficulty | Key idea |
# |---|------|------------|----------|
# | 0059 | [score_tracker.ipynb](0059.score_tracker.ipynb) | 🟢 | defaultdict + sorted tuple key |
# | 0060 | [task_scheduler_sim.ipynb](0060.task_scheduler_sim.ipynb) | 🟢 | Running clock + parse/split |
# | 0064 | [min_operations_array.ipynb](0064.min_operations_array.ipynb) | 🟢 | `prev+1−num` ops, `prev = num + ops` |
# | 0071 | [num_recent_calls.ipynb](0071.num_recent_calls.ipynb) | 🟢 | Deque — drop left while `t−q[0]>3000` |
# | 0005 | [drone_delivery.ipynb](0005.drone_delivery.ipynb) | 🟡 | Range=10, nearest station |
# | 0120 | [encode_decode_strings.ipynb](0120.encode_decode_strings.ipynb) | 🟡 | Length-prefix encode/decode |
# | 0139 | [phone_battery_rotation.ipynb](0139.phone_battery_rotation.ipynb) | 🟡 | Circular pointer, full/partial/gap |
# | 0140 | [token_ring_cooldown.ipynb](0140.token_ring_cooldown.ipynb) | 🟡 | Same — deque rotate variant |
# | 0141 | [printer_slots_round_robin.ipynb](0141.printer_slots_round_robin.ipynb) | 🟡 | Same circular template |
# | 0142 | [circular_workers_with_rest.ipynb](0142.circular_workers_with_rest.ipynb) | 🟡 | Same circular template |
# | 0145 | [bridge_crossing_simulation.ipynb](0145.bridge_crossing_simulation.ipynb) | 🔴 | 4 queues: left/right wait + left/right work |

# %% [markdown]
# ---
# <a id="trie"></a>
# ## 23 — Trie
#
# | # | File | Difficulty | Key idea |
# |---|------|------------|----------|
# | 0153 | [implement_trie.ipynb](0153.implement_trie.ipynb) | 🟡 | `{char: TrieNode}` children + `is_end`; search checks `is_end`, startsWith doesn't |
#
# ---
# <a id="hard"></a>
# ## 22 — 🔴 Hard Classics
#
# > These are Q4-level problems. Understand the pattern, don't just memorize.
#
# | # | File | Topic | Key idea |
# |---|------|-------|----------|
# | 0143 | [largest_rectangle_histogram.ipynb](0143.largest_rectangle_histogram.ipynb) | Monotonic Stack | `(start, height)` — pop on shorter bar |
# | 0144 | [trapping_rain_water.ipynb](0144.trapping_rain_water.ipynb) | Two Pointers | Move shorter side — `min(max_l, max_r) - h[i]` |
# | 0148 | [minimum_window_substring.ipynb](0148.minimum_window_substring.ipynb) | Sliding Window | `have/required` — expand r, shrink l |
# | 0149 | [edit_distance.ipynb](0149.edit_distance.ipynb) | 2D DP | Match→diag; else 1+min(diag, up, left) |
# | 0150 | [find_median_data_stream.ipynb](0150.find_median_data_stream.ipynb) | Two Heaps | lo max-heap + hi min-heap; always balance |
# | 0145 | [bridge_crossing_simulation.ipynb](0145.bridge_crossing_simulation.ipynb) | Simulation | 4 heaps: left_wait, right_wait, left_work, right_work |
#
# ---
#
# ## 🎯 GCA Game Plan
#
# | Time | Action |
# |------|--------|
# | 0:00–5:00 | Q1 — string/array, should be done fast |
# | 5:00–15:00 | Q2 — HashMap/simulation, close it out |
# | 15:00–35:00 | Q3 — medium; if stuck >10 min → skip to Q4 |
# | 35:00–60:00 | Q4 — hard; partial credit is worth it |
# | 60:00–70:00 | Return to skipped Q, review edge cases |
#
# **Submit early, submit often** — check visible test cases before the last minute.
#
# ---
# *Study guide maintained by Claude | 157 notebooks across 23 topic areas*
