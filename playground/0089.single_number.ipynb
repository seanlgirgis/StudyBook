# %% [markdown]
# ## Single Number
#
# Given a non-empty array of integers where every element appears **exactly twice** except for one — find that single element.
#
# Your solution must run in **O(n)** time and use **O(1)** extra space.
#
# ### Example
#
# - For `nums = [2,2,1]`, the output should be `1`.
# - For `nums = [4,1,2,1,2]`, the output should be `4`.
#
# ### Hint
#
# There is a one-line solution using a bitwise operator. Think about what happens when you XOR a number with itself, and what happens when you XOR a number with 0.
#
# ### Input/Output
#
# - **[execution time limit]** 4 seconds (py3)
# - **[input]** `array.integer` `nums`
# - **[output]** `integer`

# %%
# %run _timer.py

# %%
def solution(nums):
    res = 0
    for n in nums:
        res ^= n          # n^n=0 (pairs cancel), n^0=n (survivor remains)
    return res


assert solution([2,2,1])       == 1
assert solution([4,1,2,1,2])   == 4
assert solution([1])           == 1
assert solution([1,0,1])       == 0
assert solution([3,1,3,2,2])   == 1
assert solution([7,7,8,8,9])   == 9
print('All Pass!')
