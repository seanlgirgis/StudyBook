# %% [markdown]
# # Python Mastery Review 1 (CodeSignal Focus)\nUse this notebook as a frozen review deck: read the nugget, solve the exercise, then compare with your own improved version.\n

# %% [markdown]
# ## Nugget 1: HashMap + Set Baseline\nPattern: when you need fast membership, counts, or first-seen index, default to dict/set.\nChecklist: req[x] = freq.get(x, 0) + 1, seen.add(x), store first index only once.\n

# %%
# Exercise 1\n# Return first non-repeating character index, else -1\n# Input: s (str)\n\ndef first_unique_char(s: str) -> int:\n    # TODO\n    pass\n\nprint(first_unique_char('leetcode'))   # 0\nprint(first_unique_char('aabb'))       # -1\n

# %% [markdown]
# ## Nugget 2: 2D Grid Traversal + Boundaries\nPattern: define ROWS, COLS, and a direction list. Always centralize boundary checks.\nRule: most bugs in grid questions are off-by-one or invalid neighbor access.\n

# %%
# Exercise 2\n# Count islands (4-directional) in a grid of '1' and '0'\n# Use iterative DFS/BFS to avoid recursion risk\n\nfrom collections import deque\n\ndef num_islands(grid):\n    # TODO\n    pass\n\ng = [\n    ['1','1','0','0'],\n    ['1','0','0','1'],\n    ['0','0','1','1']\n]\nprint(num_islands(g))  # 2\n

# %% [markdown]
# ## Nugget 3: Sort With Intent\nPattern: sorted(data, key=lambda x: (...)) for multi-key ranking.\nRule: avoid custom comparator; key tuples are cleaner and faster to reason about.\n

# %%
# Exercise 3\n# Sort words by: 1) descending length, 2) ascending alphabetical order\n\ndef sort_words(words):\n    # TODO\n    pass\n\nprint(sort_words(['pear', 'apple', 'fig', 'banana', 'kiwi']))\n# expected: ['banana', 'apple', 'kiwi', 'pear', 'fig']\n

# %% [markdown]
# ## Nugget 4: Prefix Sum = O(1) Range Query\nPattern: prefix[i+1] = prefix[i] + arr[i] then range sum is prefix[r+1] - prefix[l].\nRule: use this anytime repeated range totals appear.\n

# %%
# Exercise 4\n# Given nums and queries [l, r], return list of range sums\n\ndef range_sum_queries(nums, queries):\n    # TODO\n    pass\n\nnums = [3, -1, 4, 2, 5]\nqueries = [(0, 2), (1, 3), (2, 4)]\nprint(range_sum_queries(nums, queries))  # [6, 5, 11]\n

# %% [markdown]
# ## Nugget 5: Sliding Window Mindset\nPattern: grow right pointer, shrink left while constraint invalid, update best answer each step.\nRule: ask 'what condition makes my window valid?'\n

# %%
# Exercise 5\n# Longest substring without repeating characters\n\ndef length_of_longest_substring(s: str) -> int:\n    # TODO\n    pass\n\nprint(length_of_longest_substring('abcabcbb'))  # 3\nprint(length_of_longest_substring('bbbbb'))     # 1\nprint(length_of_longest_substring('pwwkew'))    # 3\n
