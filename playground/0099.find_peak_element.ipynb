# %% [markdown]
# ## Find Peak Element
#
# A peak element is one that is strictly greater than its neighbors. Given an integer array `nums`, find a peak element and return its **index**. If there are multiple peaks, return any.
#
# You may assume `nums[-1]` and `nums[n]` are `-∞` (so the first/last element can be a peak).
#
# **Note:** You are not expected to provide the most optimal solution, but a solution with time complexity not worse than **O(n)** will fit within the execution time limit.
#
# ### Example
#
# - `nums = [1,2,3,1]` → `2` (nums[2]=3 is a peak)
# - `nums = [1,2,1,3,5,6,4]` → `1` or `5` (either valid)
#
# ### Input/Output
#
# - **[execution time limit]** 4 seconds (py3)
# - **[input]** `array.integer` `nums`
# - **[output]** `integer`

# %%
"""
id: lc_0162
title: Find Peak Element
source: leetcode
difficulty: medium
primary: binary search
tags: [array, binary-search]
leetcode_url: https://leetcode.com/problems/find-peak-element/
status: draft
last_updated: 2026-04-23
notes:
- key idea: binary search to find a local maximum
- time: O(log n)
- space: O(1)
"""

# ============================================================================
# File: 162_lc_0162_find_peak_element_empty.py
# LeetCode 162: Find Peak Element
# Difficulty: Medium
#
# PROBLEM STATEMENT:
# A peak element is an element that is strictly greater than its neighbors.
# Given an integer array nums, find a peak element, and return its index. 
# If the array contains multiple peaks, return the index to any of the peaks.
#
# RULES:
# - You may imagine that nums[-1] = nums[n] = -∞.
# - You must write an algorithm that runs in O(log n) time.
#
# EXAMPLES:
# Input: nums = [1,2,3,1]
# Output: 2 (Index of 3)
#
# Input: nums = [1,2,1,3,5,6,4]
# Output: 1 or 5
# ============================================================================

from typing import List

def findPeakElement(nums: List[int]) -> int:
    l , r, n = 0 , len(nums)-1, len(nums)
#    if n == 1 : return 0
    while l < r:
        mid = l + (r - l) // 2
        if nums[mid] < nums[mid+1]:    #uphiull
            l = mid +1
        else:
            r = mid
    return l


print(findPeakElement([1, 2, 3, 1]))
print(findPeakElement([1, 2, 1, 3, 5, 6, 4]))

def test():
    assert findPeakElement([1, 2, 3, 1]) == 2  # given example 1
    assert findPeakElement([1, 2, 1, 3, 5, 6, 4]) in {1, 5}  # given example 2
    assert findPeakElement([1]) == 0  # single element
    assert findPeakElement([1, 2]) == 1  # strictly increasing
    assert findPeakElement([2, 1]) == 0  # strictly decreasing
    assert findPeakElement([1, 2, 3]) == 2  # peak at end
    assert findPeakElement([3, 2, 1]) == 0  # peak at start
    assert findPeakElement([1, 3, 2]) == 1  # peak in middle
    assert findPeakElement([1, 2, 3, 4, 5]) == 4  # linear increasing
    assert findPeakElement([5, 4, 3, 2, 1]) == 0  # linear decreasing
    print('All Pass!')

test()
# Out:
# 2
# 5
# All Pass!

# %%
# %run _timer.py
# Out:
# <div style="font-family:monospace;background:#1e1e1e;color:#d4d4d4;
#             border-radius:8px;padding:14px;width:320px;user-select:none;">
#   <div id="td-dhgnus" style="font-size:2.4em;text-align:center;
#                              letter-spacing:4px;padding:8px 0;">00:00</div>
#   <div style="display:flex;gap:8px;justify-content:center;margin-top:8px;">
#     <button id="btn-start-dhgnus"
#       style="background:#0e639c;color:#fff;border:none;border-radius:4px;
#              padding:6px 16px;cursor:pointer;font-family:monospace;">Start</button>
#     <button id="btn-stop-dhgnus"
#       style="background:#5a5a5a;color:#fff;border:none;border-radius:4px;
#              padding:6px 16px;cursor:pointer;font-family:monospace;">Stop</button>
#     <button id="btn-reset-dhgnus"
#       style="background:#5a5a5a;color:#fff;border:none;border-radius:4px;
#              padding:6px 16px;cursor:pointer;font-family:monospace;">Reset</button>
#     <button id="btn-copy-dhgnus"
# ...

# %%
def localPeak(nums):
    if len(nums) == 1:
        return 0 
    if len(nums) == 2:
        return 0 if nums[0] > nums[1] else (1)
    for i in range(1, len(nums) - 1):
        if nums[i] > nums[i-1] and nums[i] > nums[i+1]:
            return i 
            
def check(result, nums):
    i = result
    left  = nums[i-1] if i > 0           else float('-inf')
    right = nums[i+1] if i < len(nums)-1 else float('-inf')
    return nums[i] > left and nums[i] > right

assert check(localPeak([1,2,3,1]),        [1,2,3,1])
assert check(localPeak([1,2,1,3,5,6,4]), [1,2,1,3,5,6,4])
assert check(localPeak([1]),             [1])
assert check(localPeak([3,1]),           [3,1])
assert check(localPeak([1,3]),           [1,3])
print('All Pass!')
# Out:
# All Pass!

# %%
def solution(nums):
    # The global maximum is always a peak
    max_val = max(nums)
    return nums.index(max_val)

# [1,2,3,1]       → index 2  (value 3, only peak)
# [1,2,1,3,5,6,4] → index 1 or 5  (value 2 or 6, both valid peaks)
# [1]             → index 0  (single element, always a peak)
# [3,1]           → index 0  (value 3 > right neighbor 1)
# [1,3]           → index 1  (value 3 > left neighbor 1)

def check(result, nums):
    i = result
    left  = nums[i-1] if i > 0           else float('-inf')
    right = nums[i+1] if i < len(nums)-1 else float('-inf')
    return nums[i] > left and nums[i] > right

assert check(solution([1,2,3,1]),        [1,2,3,1])
assert check(solution([1,2,1,3,5,6,4]), [1,2,1,3,5,6,4])
assert check(solution([1]),             [1])
assert check(solution([3,1]),           [3,1])
assert check(solution([1,3]),           [1,3])
print('All Pass!')
# Out:
# All Pass!

# %%
def solution(nums):
    # The global maximum is always a peak
    for i in range(len(nums)):
        left  = nums[i-1] if i > 0           else float('-inf')
        right = nums[i+1] if i < len(nums)-1 else float('-inf')
        if nums[i] > left and nums[i] > right:
            return i

        
        
    


# [1,2,3,1]       → index 2  (value 3, only peak)
# [1,2,1,3,5,6,4] → index 1 or 5  (value 2 or 6, both valid peaks)
# [1]             → index 0  (single element, always a peak)
# [3,1]           → index 0  (value 3 > right neighbor 1)
# [1,3]           → index 1  (value 3 > left neighbor 1)

def check(result, nums):
    i = result
    left  = nums[i-1] if i > 0           else float('-inf')
    right = nums[i+1] if i < len(nums)-1 else float('-inf')
    return nums[i] > left and nums[i] > right

assert check(solution([1,2,3,1]),        [1,2,3,1])
assert check(solution([1,2,1,3,5,6,4]), [1,2,1,3,5,6,4])
assert check(solution([1]),             [1])
assert check(solution([3,1]),           [3,1])
assert check(solution([1,3]),           [1,3])
print('All Pass!')
# Out:
# All Pass!

# %%
def solution(nums):
    # The global maximum is always a peak
    max_val = max(nums)
    return nums.index(max_val)
solution([1,2,3,1])
# Out:
# 2
