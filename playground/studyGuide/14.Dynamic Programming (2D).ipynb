# %% [markdown]
# ---
# <a id="TOC_TOP"></a>
# ---
# <a id="dp2d"></a>
# ## 14 — Dynamic Programming (2D)
#
# | # | File | Difficulty | Key idea |
# |---|------|------------|----------|
# | [0043](#s14-0043) | [unique_paths.ipynb](../0043.unique_paths.ipynb) | 🟡 | `dp[r][c] = dp[r-1][c] + dp[r][c-1]` |
# | [0044](#s14-0044) | [min_path_sum.ipynb](../0044.min_path_sum.ipynb) | 🟡 | Same grid DP with min |
# | [0114](#s14-0114) | [unique_paths_ii.ipynb](../0114.unique_paths_ii.ipynb) | 🟡 | Obstacle → zero that cell |
# | [0152](#s14-0152) | [longest_common_subsequence.ipynb](../0152.longest_common_subsequence.ipynb) | 🟡 | Match → diag+1; else → max(up, left) |
# | [0149](#s14-0149) | [edit_distance.ipynb](../0149.edit_distance.ipynb) | 🔴 | Match → diag; else → 1+min(diag,up,left) |

# %% [markdown]
# <a id="s14-0043"></a>
#  # 0043 unique_paths.ipynb
#  Difficulty: 🟡 | Key idea: `dp[r][c] = dp[r-1][c] + dp[r][c-1]`
#  [↑ Back to TOC](#TOC_TOP)

# %% [markdown]
# <a id="s14-0044"></a>
#  # 0044 min_path_sum.ipynb
#  Difficulty: 🟡 | Key idea: Same grid DP with min
#  [↑ Back to TOC](#TOC_TOP)

# %% [markdown]
# <a id="s14-0114"></a>
#  # 0114 unique_paths_ii.ipynb
#  Difficulty: 🟡 | Key idea: Obstacle → zero that cell
#  [↑ Back to TOC](#TOC_TOP)

# %% [markdown]
# <a id="s14-0152"></a>
#  # 0152 longest_common_subsequence.ipynb
#  Difficulty: 🟡 | Key idea: Match → diag+1; else → max(up, left)
#  [↑ Back to TOC](#TOC_TOP)

# %% [markdown]
# <a id="s14-0149"></a>
#  # 0149 edit_distance.ipynb
#  Difficulty: 🔴 | Key idea: Match → diag; else → 1+min(diag,up,left)
#  [↑ Back to TOC](#TOC_TOP)
