# %% [markdown]
# ---
# <a id="TOC_TOP"></a>
# ---
# <a id="backtrack"></a>
# ## 16 — Backtracking
#
# | # | File | Difficulty | Key idea |
# |---|------|------------|----------|
# | [0094](#s16-0094) | [subsets.ipynb](../0094.subsets.ipynb) | 🟡 | `backtrack(i, path)` — skip or include |
# | [0127](#s16-0127) | [permutations.ipynb](../0127.permutations.ipynb) | 🟡 | Pick any from remaining, recurse |
# | [0135](#s16-0135) | [combination_sum.ipynb](../0135.combination_sum.ipynb) | 🟡 | Reuse allowed (pass `i` not `i+1`) |

# %% [markdown]
# <a id="s16-0094"></a>
#  # 0094 subsets.ipynb
#  Difficulty: 🟡 | Key idea: `backtrack(i, path)` — skip or include
#  [↑ Back to TOC](#TOC_TOP)

# %% [markdown]
# <a id="s16-0127"></a>
#  # 0127 permutations.ipynb
#  Difficulty: 🟡 | Key idea: Pick any from remaining, recurse
#  [↑ Back to TOC](#TOC_TOP)

# %% [markdown]
# <a id="s16-0135"></a>
#  # 0135 combination_sum.ipynb
#  Difficulty: 🟡 | Key idea: Reuse allowed (pass `i` not `i+1`)
#  [↑ Back to TOC](#TOC_TOP)
