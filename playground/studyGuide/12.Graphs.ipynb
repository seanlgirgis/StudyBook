# %% [markdown]
# ---
# <a id="TOC_TOP"></a>
# ---
# <a id="graphs"></a>
# ## 12 — Graphs
#
# | # | File | Difficulty | Key idea |
# |---|------|------------|----------|
# | [0093](#s12-0093) | [course_schedule.ipynb](../0093.course_schedule.ipynb) | 🟡 | 3-state DFS cycle detection |
# | [0130](#s12-0130) | [course_schedule_ii.ipynb](../0130.course_schedule_ii.ipynb) | 🟡 | Topo sort: append post-order |
# | [0155](#s12-0155) | [network_delay_time.ipynb](../0155.network_delay_time.ipynb) | 🟡 | Dijkstra — max of all shortest paths |
# | [0154](#s12-0154) | [cheapest_flights_k_stops.ipynb](../0154.cheapest_flights_k_stops.ipynb) | 🟡 | Bellman-Ford k+1 rounds — snapshot each round |

# %% [markdown]
# <a id="s12-0093"></a>
#  # 0093 course_schedule.ipynb
#  Difficulty: 🟡 | Key idea: 3-state DFS cycle detection
#  [↑ Back to TOC](#TOC_TOP)

# %% [markdown]
# <a id="s12-0130"></a>
#  # 0130 course_schedule_ii.ipynb
#  Difficulty: 🟡 | Key idea: Topo sort: append post-order
#  [↑ Back to TOC](#TOC_TOP)

# %% [markdown]
# <a id="s12-0155"></a>
#  # 0155 network_delay_time.ipynb
#  Difficulty: 🟡 | Key idea: Dijkstra — max of all shortest paths
#  [↑ Back to TOC](#TOC_TOP)

# %% [markdown]
# <a id="s12-0154"></a>
#  # 0154 cheapest_flights_k_stops.ipynb
#  Difficulty: 🟡 | Key idea: Bellman-Ford k+1 rounds — snapshot each round
#  [↑ Back to TOC](#TOC_TOP)
