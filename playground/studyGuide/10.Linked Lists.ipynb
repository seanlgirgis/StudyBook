# %% [markdown]
# ---
# <a id="TOC_TOP10"></a>
# ---
#
# ## 10 — Linked Lists
#
# > 📖 Review [linked_list_basics.ipynb](../Basics/linked_list_basics.ipynb) first!
#
# | # | File | Difficulty | Key idea |
# |---|------|------------|----------|
# | [0048](#s10-0048) | [linked_list_reverse.ipynb](../0048.linked_list_reverse.ipynb) | 🟢 | prev/curr/nxt three-pointer |
# | [0049](#s10-0049) | [middle_linked_list.ipynb](../0049.middle_linked_list.ipynb) | 🟢 | Two-pass count, or slow/fast |
# | [0050](#s10-0050) | [linked_list_cycle.ipynb](../0050.linked_list_cycle.ipynb) | 🟢 | `id(node)` seen set; Floyd bonus |
# | [0053](#s10-0053) | [palindrome_linked_list.ipynb](../0053.palindrome_linked_list.ipynb) | 🟢 | Collect vals, `vals == vals[::-1]` |
# | [0051](#s10-0051) | [merge_two_sorted_lists.ipynb](../0051.merge_two_sorted_lists.ipynb) | 🟢 | Dummy + tail, flush remainder |
# | [0052](#s10-0052) | [remove_nth_from_end.ipynb](../0052.remove_nth_from_end.ipynb) | 🟡 | Two-pass: length − n |
# | [0113](#s10-0113) | [next_greater_node_linked_list.ipynb](../0113.next_greater_node_linked_list.ipynb) | 🟡 | Flatten → NGE stack |
# | [0126](#s10-0126) | [reorder_list.ipynb](../0126.reorder_list.ipynb) | 🟡 | Find mid → reverse half → interleave |

# %% [markdown]
# <a id="s10-0048"></a>
#  # 0048 linked_list_reverse.ipynb
#  Difficulty: 🟢 | Key idea: prev/curr/nxt three-pointer
#  [↑ Back to TOC](#TOC_TOP10)

# %% [markdown]
# <a id="s10-0049"></a>
#  # 0049 middle_linked_list.ipynb
#  Difficulty: 🟢 | Key idea: Two-pass count, or slow/fast
#  [↑ Back to TOC](#TOC_TOP10)

# %% [markdown]
# <a id="s10-0050"></a>
#  # 0050 linked_list_cycle.ipynb
#  Difficulty: 🟢 | Key idea: `id(node)` seen set; Floyd bonus
#  [↑ Back to TOC](#TOC_TOP)

# %% [markdown]
# <a id="s10-0053"></a>
#  # 0053 palindrome_linked_list.ipynb
#  Difficulty: 🟢 | Key idea: Collect vals, `vals == vals[::-1]`
#  [↑ Back to TOC](#TOC_TOP)

# %% [markdown]
# <a id="s10-0051"></a>
#  # 0051 merge_two_sorted_lists.ipynb
#  Difficulty: 🟢 | Key idea: Dummy + tail, flush remainder
#  [↑ Back to TOC](#TOC_TOP)

# %% [markdown]
# <a id="s10-0052"></a>
#  # 0052 remove_nth_from_end.ipynb
#  Difficulty: 🟡 | Key idea: Two-pass: length − n
#  [↑ Back to TOC](#TOC_TOP)

# %% [markdown]
# <a id="s10-0113"></a>
#  # 0113 next_greater_node_linked_list.ipynb
#  Difficulty: 🟡 | Key idea: Flatten → NGE stack
#  [↑ Back to TOC](#TOC_TOP)

# %% [markdown]
# <a id="s10-0126"></a>
#  # 0126 reorder_list.ipynb
#  Difficulty: 🟡 | Key idea: Find mid → reverse half → interleave
#  [↑ Back to TOC](#TOC_TOP)
