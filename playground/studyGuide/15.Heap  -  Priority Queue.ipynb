# %% [markdown]
# ---
# <a id="TOC_TOP"></a>
# ---
# <a id="heap"></a>
# ## 15 — Heap / Priority Queue
#
# | # | File | Difficulty | Key idea |
# |---|------|------------|----------|
# | [0146](#s15-0146) | [last_stone_weight.ipynb](../0146.last_stone_weight.ipynb) | 🟢 | Negate → max-heap; pop two, push diff |
# | [0036](#s15-0036) | [top_k_frequent.ipynb](../0036.top_k_frequent.ipynb) | 🟡 | Size-k min-heap, evict smallest |
# | [0065](#s15-0065) | [k_closest_points.ipynb](../0065.k_closest_points.ipynb) | 🟡 | Max-heap with `-dist` |
# | [0156](#s15-0156) | [kth_largest_stream.ipynb](../0156.kth_largest_stream.ipynb) | 🟢 | Min-heap size k — `heap[0]` = kth largest |
# | [0124](#s15-0124) | [kth_largest_element.ipynb](../0124.kth_largest_element.ipynb) | 🟡 | Min-heap size k (array, not stream) |
# | [0151](#s15-0151) | [meeting_rooms_ii.ipynb](../0151.meeting_rooms_ii.ipynb) | 🟡 | Sort by start + heap of end times |
# | [0002](#s15-0002) | [battery_swap.ipynb](../0002.battery_swap.ipynb) | 🟡 | Two heaps: ready + recovering |
# | [0138](#s15-0138) | [task_scheduler.ipynb](../0138.task_scheduler.ipynb) | 🔴 | Max-heap + cooldown deque |
# | [0150](#s15-0150) | [find_median_data_stream.ipynb](../0150.find_median_data_stream.ipynb) | 🔴 | Two heaps: lo max-heap + hi min-heap |

# %% [markdown]
# <a id="s15-0146"></a>
#  # 0146 last_stone_weight.ipynb
#  Difficulty: 🟢 | Key idea: Negate → max-heap; pop two, push diff
#  [↑ Back to TOC](#TOC_TOP)

# %% [markdown]
# <a id="s15-0036"></a>
#  # 0036 top_k_frequent.ipynb
#  Difficulty: 🟡 | Key idea: Size-k min-heap, evict smallest
#  [↑ Back to TOC](#TOC_TOP)

# %% [markdown]
# <a id="s15-0065"></a>
#  # 0065 k_closest_points.ipynb
#  Difficulty: 🟡 | Key idea: Max-heap with `-dist`
#  [↑ Back to TOC](#TOC_TOP)

# %% [markdown]
# <a id="s15-0156"></a>
#  # 0156 kth_largest_stream.ipynb
#  Difficulty: 🟢 | Key idea: Min-heap size k — `heap[0]` = kth largest
#  [↑ Back to TOC](#TOC_TOP)

# %% [markdown]
# <a id="s15-0124"></a>
#  # 0124 kth_largest_element.ipynb
#  Difficulty: 🟡 | Key idea: Min-heap size k (array, not stream)
#  [↑ Back to TOC](#TOC_TOP)

# %% [markdown]
# <a id="s15-0151"></a>
#  # 0151 meeting_rooms_ii.ipynb
#  Difficulty: 🟡 | Key idea: Sort by start + heap of end times
#  [↑ Back to TOC](#TOC_TOP)

# %% [markdown]
# <a id="s15-0002"></a>
#  # 0002 battery_swap.ipynb
#  Difficulty: 🟡 | Key idea: Two heaps: ready + recovering
#  [↑ Back to TOC](#TOC_TOP)

# %% [markdown]
# <a id="s15-0138"></a>
#  # 0138 task_scheduler.ipynb
#  Difficulty: 🔴 | Key idea: Max-heap + cooldown deque
#  [↑ Back to TOC](#TOC_TOP)

# %% [markdown]
# <a id="s15-0150"></a>
#  # 0150 find_median_data_stream.ipynb
#  Difficulty: 🔴 | Key idea: Two heaps: lo max-heap + hi min-heap
#  [↑ Back to TOC](#TOC_TOP)
