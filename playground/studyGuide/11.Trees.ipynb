# %% [markdown]
# ---
# <a id="TOC_TOP"></a>
# ---
# <a id="trees"></a>
# ## 11 — Trees
#
# > 📖 Review [binary_tree_basics.ipynb](../Basics/binary_tree_basics.ipynb) first!
#
# | # | File | Difficulty | Key idea |
# |---|------|------------|----------|
# | [0077](#s11-0077) | [max_depth_binary_tree.ipynb](../0077.max_depth_binary_tree.ipynb) | 🟢 | BFS with `(node, depth)` tuples |
# | [0078](#s11-0078) | [invert_binary_tree.ipynb](../0078.invert_binary_tree.ipynb) | 🟢 | BFS swap, tuple assignment |
# | [0079](#s11-0079) | [symmetric_tree.ipynb](../0079.symmetric_tree.ipynb) | 🟢 | `is_mirror(l, r)` crossover check |
# | [0083](#s11-0083) | [path_sum.ipynb](../0083.path_sum.ipynb) | 🟢 | Subtract val down, leaf = remainder==0 |
# | [0087](#s11-0087) | [diameter_binary_tree.ipynb](../0087.diameter_binary_tree.ipynb) | 🟢 | Post-order: height up, diameter sideways |
# | [0132](#s11-0132) | [subtree_of_another_tree.ipynb](../0132.subtree_of_another_tree.ipynb) | 🟢 | `same_tree` helper at every node |
# | [0080](#s11-0080) | [level_order_traversal.ipynb](../0080.level_order_traversal.ipynb) | 🟡 | Snapshot `len(queue)`, inner level loop |
# | [0081](#s11-0081) | [validate_bst.ipynb](../0081.validate_bst.ipynb) | 🟡 | `is_valid(node, lo, hi)` pass bounds down |
# | [0082](#s11-0082) | [lowest_common_ancestor.ipynb](../0082.lowest_common_ancestor.ipynb) | 🟡 | BST: both > curr → right, split = answer |
# | [0084](#s11-0084) | [count_good_nodes.ipynb](../0084.count_good_nodes.ipynb) | 🟡 | DFS with running max, count if val≥max |
# | [0085](#s11-0085) | [kth_smallest_bst.ipynb](../0085.kth_smallest_bst.ipynb) | 🟡 | Iterative inorder, exit at k==0 |
# | [0086](#s11-0086) | [right_side_view.ipynb](../0086.right_side_view.ipynb) | 🟡 | Level BFS, append last node per level |
# | [0129](#s11-0129) | [lca_binary_tree.ipynb](../0129.lca_binary_tree.ipynb) | 🟡 | General tree: both sides non-null → LCA |

# %% [markdown]
# <a id="s11-0077"></a>
#  # 0077 max_depth_binary_tree.ipynb
#  Difficulty: 🟢 | Key idea: BFS with `(node, depth)` tuples
#  [↑ Back to TOC](#TOC_TOP)

# %% [markdown]
# <a id="s11-0078"></a>
#  # 0078 invert_binary_tree.ipynb
#  Difficulty: 🟢 | Key idea: BFS swap, tuple assignment
#  [↑ Back to TOC](#TOC_TOP)

# %% [markdown]
# <a id="s11-0079"></a>
#  # 0079 symmetric_tree.ipynb
#  Difficulty: 🟢 | Key idea: `is_mirror(l, r)` crossover check
#  [↑ Back to TOC](#TOC_TOP)

# %% [markdown]
# <a id="s11-0083"></a>
#  # 0083 path_sum.ipynb
#  Difficulty: 🟢 | Key idea: Subtract val down, leaf = remainder==0
#  [↑ Back to TOC](#TOC_TOP)

# %% [markdown]
# <a id="s11-0087"></a>
#  # 0087 diameter_binary_tree.ipynb
#  Difficulty: 🟢 | Key idea: Post-order: height up, diameter sideways
#  [↑ Back to TOC](#TOC_TOP)

# %% [markdown]
# <a id="s11-0132"></a>
#  # 0132 subtree_of_another_tree.ipynb
#  Difficulty: 🟢 | Key idea: `same_tree` helper at every node
#  [↑ Back to TOC](#TOC_TOP)

# %% [markdown]
# <a id="s11-0080"></a>
#  # 0080 level_order_traversal.ipynb
#  Difficulty: 🟡 | Key idea: Snapshot `len(queue)`, inner level loop
#  [↑ Back to TOC](#TOC_TOP)

# %% [markdown]
# <a id="s11-0081"></a>
#  # 0081 validate_bst.ipynb
#  Difficulty: 🟡 | Key idea: `is_valid(node, lo, hi)` pass bounds down
#  [↑ Back to TOC](#TOC_TOP)

# %% [markdown]
# <a id="s11-0082"></a>
#  # 0082 lowest_common_ancestor.ipynb
#  Difficulty: 🟡 | Key idea: BST: both > curr → right, split = answer
#  [↑ Back to TOC](#TOC_TOP)

# %% [markdown]
# <a id="s11-0084"></a>
#  # 0084 count_good_nodes.ipynb
#  Difficulty: 🟡 | Key idea: DFS with running max, count if val≥max
#  [↑ Back to TOC](#TOC_TOP)

# %% [markdown]
# <a id="s11-0085"></a>
#  # 0085 kth_smallest_bst.ipynb
#  Difficulty: 🟡 | Key idea: Iterative inorder, exit at k==0
#  [↑ Back to TOC](#TOC_TOP)

# %% [markdown]
# <a id="s11-0086"></a>
#  # 0086 right_side_view.ipynb
#  Difficulty: 🟡 | Key idea: Level BFS, append last node per level
#  [↑ Back to TOC](#TOC_TOP)

# %% [markdown]
# <a id="s11-0129"></a>
#  # 0129 lca_binary_tree.ipynb
#  Difficulty: 🟡 | Key idea: General tree: both sides non-null → LCA
#  [↑ Back to TOC](#TOC_TOP)
