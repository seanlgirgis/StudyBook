# %% [markdown]
# ---
# <a id="TOC_TOP"></a>
# ---
# <a id="intervals"></a>
# ## 17 — Intervals
#
# | # | File | Difficulty | Key idea |
# |---|------|------------|----------|
# | [0088](#s17-0088) | [merge_intervals.ipynb](../0088.merge_intervals.ipynb) | 🟡 | Sort, sweep — overlap → extend end |
# | [0125](#s17-0125) | [insert_interval.ipynb](../0125.insert_interval.ipynb) | 🟡 | 3 cases: before / overlap / after |
# | [0134](#s17-0134) | [non_overlapping_intervals.ipynb](../0134.non_overlapping_intervals.ipynb) | 🟡 | Sort by end — greedy keep earliest-ending |

# %% [markdown]
# <a id="s17-0088"></a>
#  # 0088 merge_intervals.ipynb
#  Difficulty: 🟡 | Key idea: Sort, sweep — overlap → extend end
#  [↑ Back to TOC](#TOC_TOP)

# %% [markdown]
# <a id="s17-0125"></a>
#  # 0125 insert_interval.ipynb
#  Difficulty: 🟡 | Key idea: 3 cases: before / overlap / after
#  [↑ Back to TOC](#TOC_TOP)

# %% [markdown]
# <a id="s17-0134"></a>
#  # 0134 non_overlapping_intervals.ipynb
#  Difficulty: 🟡 | Key idea: Sort by end — greedy keep earliest-ending
#  [↑ Back to TOC](#TOC_TOP)
