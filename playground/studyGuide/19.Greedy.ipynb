# %% [markdown]
# ---
# <a id="TOC_TOP"></a>
# ---
# <a id="greedy"></a>
# ## 19 — Greedy
#
# | # | File | Difficulty | Key idea |
# |---|------|------------|----------|
# | [0047](#s19-0047) | [best_time_stock.ipynb](../0047.best_time_stock.ipynb) | 🟢 | Track running min buy price |
# | [0067](#s19-0067) | [jump_game.ipynb](../0067.jump_game.ipynb) | 🟡 | Track max_reach, abort if `i > max_reach` |
# | [0157](#s19-0157) | [hand_of_straights.ipynb](../0157.hand_of_straights.ipynb) | 🟡 | Counter + sorted — start each group from smallest card |
# | [0119](#s19-0119) | [gas_station.ipynb](../0119.gas_station.ipynb) | 🟡 | Sum check + reset start on negative tank |
# | [0136](#s19-0136) | [jump_game_ii.ipynb](../0136.jump_game_ii.ipynb) | 🟡 | Window `[l, r]` — expand to farthest each jump |

# %% [markdown]
# <a id="s19-0047"></a>
#  # 0047 best_time_stock.ipynb
#  Difficulty: 🟢 | Key idea: Track running min buy price
#  [↑ Back to TOC](#TOC_TOP)

# %% [markdown]
# <a id="s19-0067"></a>
#  # 0067 jump_game.ipynb
#  Difficulty: 🟡 | Key idea: Track max_reach, abort if `i > max_reach`
#  [↑ Back to TOC](#TOC_TOP)

# %% [markdown]
# <a id="s19-0157"></a>
#  # 0157 hand_of_straights.ipynb
#  Difficulty: 🟡 | Key idea: Counter + sorted — start each group from smallest card
#  [↑ Back to TOC](#TOC_TOP)

# %% [markdown]
# <a id="s19-0119"></a>
#  # 0119 gas_station.ipynb
#  Difficulty: 🟡 | Key idea: Sum check + reset start on negative tank
#  [↑ Back to TOC](#TOC_TOP)

# %% [markdown]
# <a id="s19-0136"></a>
#  # 0136 jump_game_ii.ipynb
#  Difficulty: 🟡 | Key idea: Window `[l, r]` — expand to farthest each jump
#  [↑ Back to TOC](#TOC_TOP)
