# %% [markdown]
# ---
# <a id="TOC_TOP"></a>
# ---
# <a id="dp1d"></a>
# ## 13 — Dynamic Programming (1D)
#
# | # | File | Difficulty | Key idea |
# |---|------|------------|----------|
# | [0040](#s13-0040) | [climbing_stairs.ipynb](../0040.climbing_stairs.ipynb) | 🟢 | Fibonacci two-var rolling |
# | [0072](#s13-0072) | [min_cost_climbing.ipynb](../0072.min_cost_climbing.ipynb) | 🟢 | Same two-var, `min(prev, prevprev)` |
# | [0100](#s13-0100) | [climbing_stairs_variants.ipynb](../0100.climbing_stairs_variants.ipynb) | 🟢 | Two-var spaced repeat |
# | [0047](#s13-0047) | [best_time_stock.ipynb](../0047.best_time_stock.ipynb) | 🟢 | Running min, one-pass |
# | [0041](#s13-0041) | [house_robber.ipynb](../0041.house_robber.ipynb) | 🟡 | `max(prev1, prev2 + n)` |
# | [0042](#s13-0042) | [coin_change.ipynb](../0042.coin_change.ipynb) | 🟡 | Bottom-up, `inf` seed |
# | [0123](#s13-0123) | [house_robber_ii.ipynb](../0123.house_robber_ii.ipynb) | 🟡 | Run rob on `[:-1]` and `[1:]`, take max |
# | [0118](#s13-0118) | [longest_increasing_subsequence.ipynb](../0118.longest_increasing_subsequence.ipynb) | 🟡 | `dp[i]=max(dp[j]+1)` for all j<i |
# | [0115](#s13-0115) | [decode_ways.ipynb](../0115.decode_ways.ipynb) | 🟡 | `dp[0]=1` dummy, one-digit + two-digit check |
# | [0116](#s13-0116) | [word_break.ipynb](../0116.word_break.ipynb) | 🟡 | `dp[0]=True`, `s[j:i]` in word_set |
# | [0117](#s13-0117) | [maximum_product_subarray.ipynb](../0117.maximum_product_subarray.ipynb) | 🟡 | Track cur_max + cur_min, save old_max |
# | [0137](#s13-0137) | [buy_sell_stock_cooldown.ipynb](../0137.buy_sell_stock_cooldown.ipynb) | 🟡 | 3 states: held / sold / idle |

# %% [markdown]
# <a id="s13-0040"></a>
#  # 0040 climbing_stairs.ipynb
#  Difficulty: 🟢 | Key idea: Fibonacci two-var rolling
#  [↑ Back to TOC](#TOC_TOP)

# %% [markdown]
# <a id="s13-0072"></a>
#  # 0072 min_cost_climbing.ipynb
#  Difficulty: 🟢 | Key idea: Same two-var, `min(prev, prevprev)`
#  [↑ Back to TOC](#TOC_TOP)

# %% [markdown]
# <a id="s13-0100"></a>
#  # 0100 climbing_stairs_variants.ipynb
#  Difficulty: 🟢 | Key idea: Two-var spaced repeat
#  [↑ Back to TOC](#TOC_TOP)

# %% [markdown]
# <a id="s13-0047"></a>
#  # 0047 best_time_stock.ipynb
#  Difficulty: 🟢 | Key idea: Running min, one-pass
#  [↑ Back to TOC](#TOC_TOP)

# %% [markdown]
# <a id="s13-0041"></a>
#  # 0041 house_robber.ipynb
#  Difficulty: 🟡 | Key idea: `max(prev1, prev2 + n)`
#  [↑ Back to TOC](#TOC_TOP)

# %% [markdown]
# <a id="s13-0042"></a>
#  # 0042 coin_change.ipynb
#  Difficulty: 🟡 | Key idea: Bottom-up, `inf` seed
#  [↑ Back to TOC](#TOC_TOP)

# %% [markdown]
# <a id="s13-0123"></a>
#  # 0123 house_robber_ii.ipynb
#  Difficulty: 🟡 | Key idea: Run rob on `[:-1]` and `[1:]`, take max
#  [↑ Back to TOC](#TOC_TOP)

# %% [markdown]
# <a id="s13-0118"></a>
#  # 0118 longest_increasing_subsequence.ipynb
#  Difficulty: 🟡 | Key idea: `dp[i]=max(dp[j]+1)` for all j<i
#  [↑ Back to TOC](#TOC_TOP)

# %% [markdown]
# <a id="s13-0115"></a>
#  # 0115 decode_ways.ipynb
#  Difficulty: 🟡 | Key idea: `dp[0]=1` dummy, one-digit + two-digit check
#  [↑ Back to TOC](#TOC_TOP)

# %% [markdown]
# <a id="s13-0116"></a>
#  # 0116 word_break.ipynb
#  Difficulty: 🟡 | Key idea: `dp[0]=True`, `s[j:i]` in word_set
#  [↑ Back to TOC](#TOC_TOP)

# %% [markdown]
# <a id="s13-0117"></a>
#  # 0117 maximum_product_subarray.ipynb
#  Difficulty: 🟡 | Key idea: Track cur_max + cur_min, save old_max
#  [↑ Back to TOC](#TOC_TOP)

# %% [markdown]
# <a id="s13-0137"></a>
#  # 0137 buy_sell_stock_cooldown.ipynb
#  Difficulty: 🟡 | Key idea: 3 states: held / sold / idle
#  [↑ Back to TOC](#TOC_TOP)
