# %% [markdown]
# ---
# <a id="TOC_TOP"></a>
# ---
# <a id="bits"></a>
# ## 18 — Bit Manipulation
#
# | # | File | Difficulty | Key idea |
# |---|------|------------|----------|
# | [0089](#s18-0089) | [single_number.ipynb](../0089.single_number.ipynb) | 🟢 | XOR — pairs cancel, survivor stays |
# | [0090](#s18-0090) | [missing_number.ipynb](../0090.missing_number.ipynb) | 🟢 | `n*(n+1)//2 - sum(nums)` |
# | [0096](#s18-0096) | [number_of_1_bits.ipynb](../0096.number_of_1_bits.ipynb) | 🟢 | `n&1` + right shift; `n&(n-1)` strips LSB |
# | [0092](#s18-0092) | [happy_number.ipynb](../0092.happy_number.ipynb) | 🟢 | Cycle detection with seen set |
# | [0131](#s18-0131) | [counting_bits.ipynb](../0131.counting_bits.ipynb) | 🟢 | `dp[i] = dp[i>>1] + (i&1)` |
# | [0147](#s18-0147) | [sum_of_two_integers.ipynb](../0147.sum_of_two_integers.ipynb) | 🟡 | `a^b` = sum, `(a&b)<<1` = carry; 32-bit mask for Python |

# %% [markdown]
# <a id="s18-0089"></a>
#  # 0089 single_number.ipynb
#  Difficulty: 🟢 | Key idea: XOR — pairs cancel, survivor stays
#  [↑ Back to TOC](#TOC_TOP)

# %% [markdown]
# <a id="s18-0090"></a>
#  # 0090 missing_number.ipynb
#  Difficulty: 🟢 | Key idea: `n*(n+1)//2 - sum(nums)`
#  [↑ Back to TOC](#TOC_TOP)

# %% [markdown]
# <a id="s18-0096"></a>
#  # 0096 number_of_1_bits.ipynb
#  Difficulty: 🟢 | Key idea: `n&1` + right shift; `n&(n-1)` strips LSB
#  [↑ Back to TOC](#TOC_TOP)

# %% [markdown]
# <a id="s18-0092"></a>
#  # 0092 happy_number.ipynb
#  Difficulty: 🟢 | Key idea: Cycle detection with seen set
#  [↑ Back to TOC](#TOC_TOP)

# %% [markdown]
# <a id="s18-0131"></a>
#  # 0131 counting_bits.ipynb
#  Difficulty: 🟢 | Key idea: `dp[i] = dp[i>>1] + (i&1)`
#  [↑ Back to TOC](#TOC_TOP)

# %% [markdown]
# <a id="s18-0147"></a>
#  # 0147 sum_of_two_integers.ipynb
#  Difficulty: 🟡 | Key idea: `a^b` = sum, `(a&b)<<1` = carry; 32-bit mask for Python
#  [↑ Back to TOC](#TOC_TOP)
