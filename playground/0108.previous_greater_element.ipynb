# %% [markdown]
# ## Previous Greater Element
#
# Given an array `nums`, for each element return the first element to its **left** that is **greater**. If none exists, return `-1`.
#
# ### Example
#
# - `[4,5,2,10,8]` → `[-1,-1,5,-1,10]`
# - `[1,2,3]` → `[-1,-1,-1]`
# - `[3,2,1]` → `[-1,3,2]`
#
# ### Pattern
# The answer for each element is the **top of the stack** at the moment you push — not on pop.
# Pop anything smaller-or-equal before pushing (maintain decreasing stack).

# %%
# %run _timer.py
# Out:
# <div style="font-family:monospace;background:#1e1e1e;color:#d4d4d4;
#             border-radius:8px;padding:14px;width:320px;user-select:none;">
#   <div id="td-qgmvbc" style="font-size:2.4em;text-align:center;
#                              letter-spacing:4px;padding:8px 0;">00:00</div>
#   <div style="display:flex;gap:8px;justify-content:center;margin-top:8px;">
#     <button id="btn-start-qgmvbc"
#       style="background:#0e639c;color:#fff;border:none;border-radius:4px;
#              padding:6px 16px;cursor:pointer;font-family:monospace;">Start</button>
#     <button id="btn-stop-qgmvbc"
#       style="background:#5a5a5a;color:#fff;border:none;border-radius:4px;
#              padding:6px 16px;cursor:pointer;font-family:monospace;">Stop</button>
#     <button id="btn-reset-qgmvbc"
#       style="background:#5a5a5a;color:#fff;border:none;border-radius:4px;
#              padding:6px 16px;cursor:pointer;font-family:monospace;">Reset</button>
#     <button id="btn-copy-qgmvbc"
#       style="background:#16825d;color:#fff;border:none;border-radius:4px;
#              padding:6px 16px;cursor:pointer;font-family:monospace;">Copy</button>
#   </div>
#   <div id="tm-qgmvbc" style="text-align:center;font-size:0.78em;
#                               color:#4ec9b0;height:18px;margin-top:6px;"></div>
# </div>
#
# <script>
# (function() {
#   var disp  = document.getElementById('td-qgmvbc');
#   var msg   = document.getElementById('tm-qgmvbc');
#   var start = null, elapsed = 0, iv = null, running = false;
#
#   function fmt(ms) {
#     var s = Math.floor(ms / 1000);
#     var m = Math.floor(s / 60).toString().padStart(2, '0');
#     return m + ':' + (s % 60).toString().padStart(2, '0');
#   }
#
#   document.getElementById('btn-start-qgmvbc').addEventListener('click', function() {
#     if (!running) {
#       running = true;
#       start = Date.now() - elapsed;
#       iv = setInterval(function() {
#         elapsed = Date.now() - start;
#         disp.innerText = fmt(elapsed);
#       }, 500);
#     }
#   });
#
#   document.getElementById('btn-stop-qgmvbc').addEventListener('click', function() {
#     if (running) { running = false; clearInterval(iv); }
#   });
#
#   document.getElementById('btn-reset-qgmvbc').addEventListener('click', function() {
#     running = false; clearInterval(iv);
#     elapsed = 0; disp.innerText = '00:00'; msg.innerText = '';
#   });
#
#   document.getElementById('btn-copy-qgmvbc').addEventListener('click', function() {
#     var txt = '# solved in ' + disp.innerText;
#     if (navigator.clipboard) {
#       navigator.clipboard.writeText(txt).then(function() {
#         msg.innerText = 'Copied — ' + txt;
#         setTimeout(function() { msg.innerText = ''; }, 2500);
#       });
#     } else {
#       msg.innerText = txt;
#     }
#   });
# })();
# </script>

# %%
def solution(nums):
    n = len(nums)
    ans = [-1] * n
    stack = []
    for i in range(n - 1, -1, -1):
        val = nums[i]
        while stack and val > nums[stack[-1]]:
            ans[stack.pop()] = val
        stack.append(i)
    return ans


assert solution([4,5,2,10,8]) == [-1,-1,5,-1,10]
assert solution([1,2,3])      == [-1,-1,-1]
assert solution([3,2,1])      == [-1,3,2]
assert solution([1])          == [-1]
assert solution([2,2,2])      == [-1,-1,-1]
print('All Pass!')
# Out:
# All Pass!

# %%
# ── STANDARD: left-to-right, answer is stack top at push time ─────────────────
# Maintain a decreasing stack of VALUES.
# Before pushing, pop anything smaller-or-equal — they can't be the previous greater.
# Whatever remains on top IS the previous greater for the current element.

def solution_standard(nums):
    ans = []
    stack = []   # stores values, decreasing bottom→top
    for val in nums:
        while stack and val >= stack[-1]:
            stack.pop()
        ans.append(stack[-1] if stack else -1)
        stack.append(val)
    return ans


assert solution_standard([4,5,2,10,8]) == [-1,-1,5,-1,10]
assert solution_standard([1,2,3])      == [-1,-1,-1]
assert solution_standard([3,2,1])      == [-1,3,2]
assert solution_standard([1])          == [-1]
assert solution_standard([2,2,2])      == [-1,-1,-1]
print('solution_standard pass')
# Out:
# solution_standard pass
