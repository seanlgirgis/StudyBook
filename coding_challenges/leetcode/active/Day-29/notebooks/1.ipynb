# %% [markdown]
# # LC 1 — Two Sum
# **Difficulty:** Easy | **Category:** Array / HashMap | **Pattern:** Complement Lookup
#
# <div style="border-left:4px solid purple; padding:10px 16px;
# background:#f5f0ff; margin-top:12px;">
# <strong>Core Insight:</strong> For every number you visit, the answer
# you need is <code>target - num</code>. Store what you have seen so
# far in a HashMap so each complement check is O(1).
# </div>

# %% [markdown]
# ## Official Problem Statement
#
# Given an array of integers `nums` and an integer `target`, return
# **indices** of the two numbers such that they add up to `target`.
#
# You may assume that each input would have **exactly one solution**,
# and you may not use the same element twice.
#
# You can return the answer in any order.
#
# **Constraints:**
# - `2 <= nums.length <= 10^4`
# - `-10^9 <= nums[i] <= 10^9`
# - `-10^9 <= target <= 10^9`
# - Only one valid answer exists.

# %% [markdown]
# ## What This Is Actually Asking
#
# You have a list of numbers and a target total.
# Find two numbers in the list that add up to that total.
# Return their positions (indices), not the numbers themselves.
# You cannot use the same position twice.
# There is always exactly one correct pair.

# %% [markdown]
# ## Walk Through an Example by Hand
#
# ```
# nums = [2, 7, 11, 15], target = 9
#
# Step 1: i=0, num=2
#   complement = 9 - 2 = 7
#   7 not in map  →  store {2: 0}
#
# Step 2: i=1, num=7
#   complement = 9 - 7 = 2
#   2 IS in map at index 0  →  return [0, 1]
# ```
#
# We never needed to look past index 1.

# %% [markdown]
# ## The Picture
#
# HashMap state as we scan `[2, 7, 11, 15]`, target = 9:
#
# ```
# After visiting each number:
#
#  i  |  num  | complement | map before check      | action
# ----+-------+------------+-----------------------+--------
#  0  |   2   |     7      | {}                    | store 2→0
#  1  |   7   |     2      | {2:0}                 | FOUND! return [0,1]
#  2  |  11   |    -2      | (never reached)       |
#  3  |  15   |    -6      | (never reached)       |
#
# HashMap: { num → index }
#   Key   = number we have seen
#   Value = its index in nums
# ```
#
# The map acts as a "have I seen the complement yet?" registry.

# %% [markdown]
# ## When To Use This Pattern
#
# - When you need to find **two elements** that satisfy a condition
#   together, think complement lookup.
# - When the brute-force is O(n²) nested loops, think HashMap O(n).
# - When you see "find pair that sums to X", think store-and-check.
# - When index positions matter (not just values), think `value→index`
#   map.
# - When the problem guarantees exactly one answer, one-pass HashMap
#   is safe.

# %% [markdown]
# ## The Approach
#
# Walk through the array once keeping a HashMap of every number
# seen so far mapped to its index.
# For each new number, compute its complement (`target - num`) and
# check if that complement already lives in the map.
# If it does, we have our pair — return the stored index and the
# current index immediately.
# If not, add the current number and index to the map and continue.

# %%
from typing import List  # typed signatures

# %%
def test_harness(func):
    """Run test cases for Two Sum."""
    tests = [
        # (nums, target, expected)
        ([2, 7, 11, 15], 9,  [0, 1]),
        ([3, 2, 4],      6,  [1, 2]),
        ([3, 3],         6,  [0, 1]),
        ([-1, -2, -3, -4, -5], -8, [2, 4]),
        ([0, 4, 3, 0],   0,  [0, 3]),
    ]
    passed = 0
    for nums, target, expected in tests:
        result = func(nums, target)
        # order of pair may vary — sort both before comparing
        if sorted(result) == sorted(expected):
            print(f"PASSED | nums={nums}, target={target}")
            passed += 1
        else:
            print(
                f"FAILED | nums={nums}, target={target} "
                f"| got {result}, expected {expected}"
            )
    print(f"\n{passed}/{len(tests)} tests passed.")

# %%
def two_sum(nums: List[int], target: int) -> List[int]:
    """
    Given nums and target, return indices of two numbers
    that add up to target.

    Approach:
      One-pass HashMap. For each num, check if complement
      (target - num) is already stored. If yes, return pair.
      If no, store num→index and continue.

    Time:  O(n)  — single pass through nums
    Space: O(n)  — HashMap stores up to n entries
    """
    pass


# --- debug prints (expected in comments) ---
print(two_sum([2, 7, 11, 15], 9))   # [0, 1]
print(two_sum([3, 2, 4], 6))        # [1, 2]
print(two_sum([3, 3], 6))           # [0, 1]
print(two_sum([-1, -2, -3, -4, -5], -8))  # [2, 4]
print(two_sum([0, 4, 3, 0], 0))     # [0, 3]

# %%
# Uncomment and run when solution is ready
# test_harness(two_sum)

# %% [markdown]
# ## Complexity
#
# | Approach      | Time   | Space  |
# |---------------|--------|--------|
# | Brute Force   | O(n²)  | O(1)   |
# | HashMap (optimal) | O(n) | O(n) |

# %% [markdown]
# ## Real World Connection
#
# At Citi, DynamoDB lookups for 6,000 endpoint records follow the
# same complement-lookup pattern: given a transaction ID, you
# instantly check a pre-built index rather than scanning all rows.
# An AWS Lambda correlating two telemetry events — e.g., a request
# log paired with its response log — uses a HashMap keyed on
# correlation ID to find the match in one pass.
# ETL deduplication pipelines store seen record hashes in a set
# and check membership in O(1), the exact same pattern scaled to
# millions of rows.

# %% [markdown]
# > **Simplicity and clarity is Gold.** — Sean's Study Mantra
