# %% [markdown]
# # Apache Kafka — First Contact
#
# Kafka is a distributed event streaming platform built to handle continuous flows of data at high throughput with strong durability. Instead of treating data as isolated rows written directly into downstream systems, Kafka treats events as an ordered log that can be written once and read many times by independent consumers.
#
# Kafka exists because tightly coupling producers to databases, services, and analytics pipelines creates bottlenecks and fragile dependencies. In a modern data engineering stack, Kafka sits between event producers and downstream consumers so that ingestion, alerting, analytics, and machine learning pipelines can scale independently.
#
# In Citi's telemetry system, 6,000+ endpoints emit latency and error events continuously. A database cannot absorb that write rate without becoming a bottleneck. Kafka decouples producers (monitoring agents) from consumers (alerting, analytics, ML pipelines).
#
# ```text
#                  +------------------+
#                  | Monitoring Agent |
#                  +------------------+
#                           |
#                           v
#                     +-------------+
#                     | Kafka Topic |
#                     +-------------+
#                      /           \
#                     v             v
#         +-------------------+   +--------------------+
#         | Alerting Consumer |   | Analytics Consumer |
#         +-------------------+   +--------------------+
# ```

# %%
# %pip install confluent-kafka psycopg2-binary

from confluent_kafka import Producer, Consumer
import psycopg2
import json
import time
from datetime import datetime
import uuid
# Out:
# Requirement already satisfied: confluent-kafka in C:\py_venv\proj_educate\Lib\site-packages (2.13.2)
# Requirement already satisfied: psycopg2-binary in C:\py_venv\proj_educate\Lib\site-packages (2.9.9)
# Note: you may need to restart the kernel to use updated packages.

# %%
KAFKA_CONFIG = {
    "bootstrap.servers": "localhost:9092"
}

PG_CONFIG = {
    "host": "localhost",
    "port": 5432,
    "dbname": "de_telemetry",
    "user": "de_admin",
    "password": "DeAdmin2026!"
}

print(f"Kafka bootstrap: {KAFKA_CONFIG['bootstrap.servers']}")
# Out:
# Kafka bootstrap: localhost:9092

# %% [markdown]
# ## Topic Setup
#
# A Kafka **topic** is the named stream where events are written. A topic is split into **partitions** so multiple producers and consumers can work in parallel. The **replication factor** controls how many copies of the data Kafka keeps across brokers for durability and availability. In this local lab, we use 3 partitions and replication factor 1 because there is only one broker.

# %%
from confluent_kafka.admin import AdminClient, NewTopic
from confluent_kafka import KafkaException

admin = AdminClient(KAFKA_CONFIG)
topic_name = "citi.alerts"

existing_topics = admin.list_topics(timeout=10).topics
if topic_name in existing_topics:
    print("Topic citi.alerts already exists — OK")
else:
    topic = NewTopic(topic_name, num_partitions=3, replication_factor=1)
    futures = admin.create_topics([topic])
    try:
        futures[topic_name].result()
        print("Topic citi.alerts created (3 partitions, RF=1)")
    except Exception as exc:
        message = str(exc)
        if "TOPIC_ALREADY_EXISTS" in message or "already exists" in message.lower():
            print("Topic citi.alerts already exists — OK")
        else:
            raise
# Out:
# Topic citi.alerts already exists — OK

# %% [markdown]
# ## Load Alerts from Postgres
#
# We pull 100 HIGH/CRITICAL alerts from Postgres to produce into Kafka.

# %%
def load_alerts(limit=100):
    sql = '''
        SELECT
            alert_id,
            endpoint_id,
            severity,
            message,
            created_at
        FROM alerts
        WHERE severity IN ('HIGH', 'CRITICAL')
        ORDER BY created_at DESC
        LIMIT %s
    '''
    with psycopg2.connect(**PG_CONFIG) as conn:
        with conn.cursor() as cur:
            cur.execute("SET search_path TO public, telemetry")
            cur.execute(sql, (limit,))
            rows = cur.fetchall()

    alerts = []
    for alert_id, endpoint_id, severity, message, created_at in rows:
        alerts.append(
            {
                "alert_id": alert_id,
                "endpoint_id": endpoint_id,
                "severity": severity,
                "message": message,
                "created_at": created_at.isoformat() if created_at is not None else None
            }
        )
    return alerts

alerts = load_alerts(limit=100)
print(f"Loaded {len(alerts)} alerts from Postgres")
# Out:
# Loaded 100 alerts from Postgres

# %% [markdown]
# ## Producer
#
# A Kafka **producer** publishes records into a topic. Each record can have a **key** and a **value**. Here, the key is the alert ID and the value is JSON. The delivery callback tells us whether Kafka acknowledged each message successfully.

# %%
def delivery_callback(err, msg):
    if err is not None:
        print(f"✗ delivery failed for key={msg.key().decode('utf-8') if msg.key() else None}: {err}")
    else:
        print(
            f"✓ delivered topic={msg.topic()} partition={msg.partition()} "
            f"offset={msg.offset()} key={msg.key().decode('utf-8') if msg.key() else None}"
        )

producer = Producer(KAFKA_CONFIG)

for alert in alerts:
    producer.produce(
        topic_name,
        key=str(alert["alert_id"]),
        value=json.dumps(alert),
        callback=delivery_callback
    )
    producer.poll(0)

producer.flush()
print(f"Produced {len(alerts)} alerts to {topic_name}")
# Out:
# ✓ delivered topic=citi.alerts partition=1 offset=40 key=16600
# ✓ delivered topic=citi.alerts partition=1 offset=41 key=21512
# ✓ delivered topic=citi.alerts partition=1 offset=42 key=14226
# ✓ delivered topic=citi.alerts partition=1 offset=43 key=6406
# ✓ delivered topic=citi.alerts partition=1 offset=44 key=22797
# ✓ delivered topic=citi.alerts partition=1 offset=45 key=16522
# ✓ delivered topic=citi.alerts partition=1 offset=46 key=5767
# ✓ delivered topic=citi.alerts partition=1 offset=47 key=24831
# ✓ delivered topic=citi.alerts partition=1 offset=48 key=22213
# ✓ delivered topic=citi.alerts partition=1 offset=49 key=2763
# ✓ delivered topic=citi.alerts partition=1 offset=50 key=23029
# ✓ delivered topic=citi.alerts partition=1 offset=51 key=13721
# ✓ delivered topic=citi.alerts partition=1 offset=52 key=3606
# ✓ delivered topic=citi.alerts partition=1 offset=53 key=2575
# ✓ delivered topic=citi.alerts partition=1 offset=54 key=9537
# ✓ delivered topic=citi.alerts partition=1 offset=55 key=22437
# ✓ delivered topic=citi.alerts partition=1 offset=56 key=12412
# ✓ delivered topic=citi.alerts partition=1 offset=57 key=23165
# ✓ delivered topic=citi.alerts partition=1 offset=58 key=1417
# ✓ delivered topic=citi.alerts partition=1 offset=59 key=12235
# ✓ delivered topic=citi.alerts partition=1 offset=60 key=5870
# ✓ delivered topic=citi.alerts partition=1 offset=61 key=17113
# ✓ delivered topic=citi.alerts partition=1 offset=62 key=11396
# ✓ delivered topic=citi.alerts partition=1 offset=63 key=16520
# ✓ delivered topic=citi.alerts partition=1 offset=64 key=5630
# ✓ delivered topic=citi.alerts partition=1 offset=65 key=18209
# ✓ delivered topic=citi.alerts partition=1 offset=66 key=14807
# ✓ delivered topic=citi.alerts partition=1 offset=67 key=4186
# ✓ delivered topic=citi.alerts partition=1 offset=68 key=14950
# ✓ delivered topic=citi.alerts partition=1 offset=69 key=18779
# ✓ delivered topic=citi.alerts partition=1 offset=70 key=20110
# ✓ delivered topic=citi.alerts partition=1 offset=71 key=24543
# ✓ delivered topic=citi.alerts partition=1 offset=72 key=4114
# ✓ delivered topic=citi.alerts partition=1 offset=73 key=24030
# ✓ delivered topic=citi.alerts partition=1 offset=74 key=997
# ✓ delivered topic=citi.alerts partition=1 offset=75 key=17985
# ✓ delivered topic=citi.alerts partition=1 offset=76 key=19396
# ✓ delivered topic=citi.alerts partition=1 offset=77 key=24246
# ✓ delivered topic=citi.alerts partition=1 offset=78 key=14976
# ✓ delivered topic=citi.alerts partition=1 offset=79 key=6617
# ✓ delivered topic=citi.alerts partition=2 offset=28 key=19547
# ✓ delivered topic=citi.alerts partition=2 offset=29 key=23839
# ✓ delivered topic=citi.alerts partition=2 offset=30 key=16922
# ✓ delivered topic=citi.alerts partition=2 offset=31 key=11470
# ✓ delivered topic=citi.alerts partition=2 offset=32 key=16644
# ✓ delivered topic=citi.alerts partition=2 offset=33 key=1159
# ✓ delivered topic=citi.alerts partition=2 offset=34 key=6085
# ✓ delivered topic=citi.alerts partition=2 offset=35 key=5360
# ✓ delivered topic=citi.alerts partition=2 offset=36 key=8428
# ✓ delivered topic=citi.alerts partition=2 offset=37 key=23983
# ✓ delivered topic=citi.alerts partition=2 offset=38 key=16277
# ✓ delivered topic=citi.alerts partition=2 offset=39 key=21860
# ✓ delivered topic=citi.alerts partition=2 offset=40 key=137
# ✓ delivered topic=citi.alerts partition=2 offset=41 key=6708
# ✓ delivered topic=citi.alerts partition=2 offset=42 key=16441
# ✓ delivered topic=citi.alerts partition=2 offset=43 key=2308
# ✓ delivered topic=citi.alerts partition=2 offset=44 key=3504
# ✓ delivered topic=citi.alerts partition=2 offset=45 key=13310
# ✓ delivered topic=citi.alerts partition=2 offset=46 key=11402
# ✓ delivered topic=citi.alerts partition=2 offset=47 key=9591
# ✓ delivered topic=citi.alerts partition=2 offset=48 key=14186
# ✓ delivered topic=citi.alerts partition=2 offset=49 key=124
# ✓ delivered topic=citi.alerts partition=2 offset=50 key=20928
# ✓ delivered topic=citi.alerts partition=2 offset=51 key=22270
# ✓ delivered topic=citi.alerts partition=2 offset=52 key=20817
# ✓ delivered topic=citi.alerts partition=2 offset=53 key=2938
# ✓ delivered topic=citi.alerts partition=2 offset=54 key=14416
# ✓ delivered topic=citi.alerts partition=2 offset=55 key=350
# ✓ delivered topic=citi.alerts partition=0 offset=32 key=5476
# ✓ delivered topic=citi.alerts partition=0 offset=33 key=8030
# ✓ delivered topic=citi.alerts partition=0 offset=34 key=2027
# ✓ delivered topic=citi.alerts partition=0 offset=35 key=23449
# ✓ delivered topic=citi.alerts partition=0 offset=36 key=13258
# ✓ delivered topic=citi.alerts partition=0 offset=37 key=15326
# ✓ delivered topic=citi.alerts partition=0 offset=38 key=1197
# ✓ delivered topic=citi.alerts partition=0 offset=39 key=4580
# ✓ delivered topic=citi.alerts partition=0 offset=40 key=16102
# ✓ delivered topic=citi.alerts partition=0 offset=41 key=8922
# ✓ delivered topic=citi.alerts partition=0 offset=42 key=21471
# ✓ delivered topic=citi.alerts partition=0 offset=43 key=23541
# ✓ delivered topic=citi.alerts partition=0 offset=44 key=11267
# ✓ delivered topic=citi.alerts partition=0 offset=45 key=11657
# ✓ delivered topic=citi.alerts partition=0 offset=46 key=23377
# ✓ delivered topic=citi.alerts partition=0 offset=47 key=1565
# ✓ delivered topic=citi.alerts partition=0 offset=48 key=24110
# ✓ delivered topic=citi.alerts partition=0 offset=49 key=16096
# ✓ delivered topic=citi.alerts partition=0 offset=50 key=6473
# ✓ delivered topic=citi.alerts partition=0 offset=51 key=8807
# ✓ delivered topic=citi.alerts partition=0 offset=52 key=3442
# ✓ delivered topic=citi.alerts partition=0 offset=53 key=7870
# ✓ delivered topic=citi.alerts partition=0 offset=54 key=23711
# ✓ delivered topic=citi.alerts partition=0 offset=55 key=6997
# ✓ delivered topic=citi.alerts partition=0 offset=56 key=2216
# ✓ delivered topic=citi.alerts partition=0 offset=57 key=3956
# ✓ delivered topic=citi.alerts partition=0 offset=58 key=9124
# ✓ delivered topic=citi.alerts partition=0 offset=59 key=2317
# ✓ delivered topic=citi.alerts partition=0 offset=60 key=198
# ✓ delivered topic=citi.alerts partition=0 offset=61 key=16287
# ✓ delivered topic=citi.alerts partition=0 offset=62 key=23461
# ✓ delivered topic=citi.alerts partition=0 offset=63 key=9994
# Produced 100 alerts to citi.alerts

# %% [markdown]
# ## Consumer
#
# A Kafka **consumer** reads records from topics. Consumers join **consumer groups** so Kafka can distribute partitions across readers. An **offset** is the position of a message inside a partition. With `auto.offset.reset=earliest`, a brand-new consumer group starts from the beginning of the topic.

# %%
consumer = Consumer(
    {
        "bootstrap.servers": KAFKA_CONFIG["bootstrap.servers"],
        "group.id": f"notebook-group-1-{uuid.uuid4()}",
        "auto.offset.reset": "earliest"
    }
)

consumer.subscribe([topic_name])

consumed_messages = []
idle_start = None          # only start countdown after first message arrives
start_time = time.time()   # hard cap: 15s before first message

try:
    while True:
        msg = consumer.poll(timeout=1.0)

        if msg is None:
            if idle_start is None:
                # Still waiting for partition assignment + first message
                if time.time() - start_time >= 15:
                    break
            else:
                # We've received at least one message; exit after 3s of silence
                if time.time() - idle_start >= 3:
                    break
            continue

        # Got a message — reset idle timer
        idle_start = time.time()

        if msg.error():
            print(f"Consumer error: {msg.error()}")
            continue

        payload = json.loads(msg.value().decode("utf-8"))
        consumed_messages.append(payload)

        if len(consumed_messages) >= 100:
            break
finally:
    consumer.close()

for i, payload in enumerate(consumed_messages[:5], start=1):
    print(f"Message {i}")
    print(json.dumps(payload, indent=2))
    print("-" * 60)

count = len(consumed_messages)
print(f"Consumed {count} messages from {topic_name}")
# Out:
# Message 1
# {
#   "alert_id": 19547,
#   "endpoint_id": 9519,
#   "severity": "CRITICAL",
#   "message": "Load average exceeded 4x CPU count",
#   "created_at": "2026-03-23T11:09:58.063609+00:00"
# }
# ------------------------------------------------------------
# Message 2
# {
#   "alert_id": 23839,
#   "endpoint_id": 5339,
#   "severity": "HIGH",
#   "message": "Network throughput dropped below SLA threshold",
#   "created_at": "2026-03-23T09:23:49.063609+00:00"
# }
# ------------------------------------------------------------
# Message 3
# {
#   "alert_id": 16922,
#   "endpoint_id": 3701,
#   "severity": "CRITICAL",
#   "message": "TCP connection pool exhausted on port 5432",
#   "created_at": "2026-03-23T09:23:45.063609+00:00"
# }
# ------------------------------------------------------------
# Message 4
# {
#   "alert_id": 11470,
#   "endpoint_id": 9343,
#   "severity": "CRITICAL",
#   "message": "Memory usage at 95% \u2014 potential OOM imminent",
#   "created_at": "2026-03-23T09:04:19.063609+00:00"
# }
# ------------------------------------------------------------
# Message 5
# {
#   "alert_id": 16644,
#   "endpoint_id": 7443,
#   "severity": "HIGH",
#   "message": "Health check failed: HTTP 503 from db-96.baker-smith.info",
#   "created_at": "2026-03-23T08:16:22.063609+00:00"
# }
# ------------------------------------------------------------
# Consumed 100 messages from citi.alerts

# %% [markdown]
# ## Offset Exploration
#
# Offsets matter because they are Kafka's replay and recovery mechanism. A consumer does not just read "the topic" — it reads from a specific partition and offset. That offset acts like a bookmark. If a consumer crashes, Kafka can resume from the last committed offset instead of starting over.

# %%
from confluent_kafka import TopicPartition

admin = AdminClient(KAFKA_CONFIG)
metadata = admin.list_topics(topic=topic_name, timeout=10)
partitions = sorted(metadata.topics[topic_name].partitions.keys())

offset_consumer = Consumer(
    {
        "bootstrap.servers": KAFKA_CONFIG["bootstrap.servers"],
        "group.id": f"offset-inspector-{uuid.uuid4()}",
        "auto.offset.reset": "earliest"
    }
)

offset_lines = []
try:
    for partition_id in partitions:
        tp = TopicPartition(topic_name, partition_id)
        low, high = offset_consumer.get_watermark_offsets(tp, timeout=10)
        offset_lines.append(f"Partition {partition_id}: offset {high}")
finally:
    offset_consumer.close()

print(", ".join(offset_lines))
# Out:
# Partition 0: offset 64, Partition 1: offset 80, Partition 2: offset 56

# %% [markdown]
# ## What Just Happened
#
# - A Kafka topic acted as a **durable append-only log** for alert events.
# - The producer wrote alert records once, and a consumer group read them independently without touching the producer.
# - The **offset** served as a bookmark so consumers can replay or resume processing safely.
# - The **replication factor** controls durability and availability; in this lab it is 1 because there is only one broker.
# - Kafka beats a database queue here because it is designed for high-throughput fan-out, where many downstream consumers need the same stream.
#
# This pattern scales to 6,000 endpoints emitting every 10 seconds = 600 events/sec. Kafka handles this trivially. A Postgres INSERT loop would not.

# %% [markdown]
# ## Next Steps
#
# - Run `kafka_concepts.md` to lock in the vocabulary
# - T1-A2 is next — concept definitions before the deep dive in Round 2
